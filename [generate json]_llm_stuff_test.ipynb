# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Please download and change path

# %% [markdown]
# Data: set of [ticker, headline, date]
#
# File name: headlines.csv
#
# Downloaded from: https://www.kaggle.com/code/shtrausslearning/news-sentiment-based-trading-strategy/input

# %%
# CHANGE TO YOUR PATH

# %%
#headlines_file_path = "/content/drive/MyDrive/LST/DS_SS2023/headlines_archive.zip"

# %%
#headlines_unzipped_file_path = "/content/drive/MyDrive/LST/DS_SS2023/headlines_archive_unzipped"

# %%
headlines_csv_path = "/content/drive/MyDrive/LST/DS_SS2023/headlines.csv"

# %%
tickers_csv_base_path = "/content/drive/MyDrive/LST/DS_SS2023/stocks_"

# %%
output_base_path = "/content/drive/MyDrive/LST/DS_SS2023/"

# %% [markdown]
# # Install and Imports

# %% [markdown]
# ## Installs

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.21)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (3.4)

# %%
pip install sentence-transformers==0.3.0
# Out:
# Collecting sentence-transformers==0.3.0
#   Downloading sentence-transformers-0.3.0.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers>=3.0.2 (from sentence-transformers==0.3.0)
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 78.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==0.3.0) (4.65.0)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==0.3.0) (2.0.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==0.3.0) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==0.3.0) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==0.3.0) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==0.3.0) (3.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->sentence-transformers==0.3.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->sentence-transformers==0.3.0) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->sentence-transformers==0.3.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->sentence-transformers==0.3.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->sentence-transformers==0.3.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->sentence-transformers==0.3.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.1->sentence-transformers==0.3.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.1->sentence-transformers==0.3.0) (16.0.6)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers>=3.0.2->sentence-transformers==0.3.0)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 25.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.2->sentence-transformers==0.3.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.2->sentence-transformers==0.3.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.2->sentence-transformers==0.3.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.2->sentence-transformers==0.3.0) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=3.0.2->sentence-transformers==0.3.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=3.0.2->sentence-transformers==0.3.0)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==0.3.0) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==0.3.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==0.3.0) (3.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=3.0.2->sentence-transformers==0.3.0) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.1->sentence-transformers==0.3.0) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=3.0.2->sentence-transformers==0.3.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=3.0.2->sentence-transformers==0.3.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=3.0.2->sentence-transformers==0.3.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=3.0.2->sentence-transformers==0.3.0) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.1->sentence-transformers==0.3.0) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.3.0-py3-none-any.whl size=86744 sha256=0fb7002fefc0d90d4515f77aba4f45e91bc040400efc539326a9cc7850613785
#   Stored in directory: /root/.cache/pip/wheels/2b/47/66/db4cf7cee20c1a4dcdcf947ce68b80b4893a979c70fcd2b3d2
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 sentence-transformers-0.3.0 tokenizers-0.13.3 transformers-4.30.2

# %%
pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.7.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.3.8 (from keybert)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.22.4)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.14.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.30.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.3.8->keybert)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.7.0-py3-none-any.whl size=23777 sha256=0a4683018649d21966f02918cc375a8d897aedb6ccdd137ea04bca1b3579f4f6
#   Stored in directory: /root/.cache/pip/wheels/66/8d/e6/b0e2f8d883b0fd51819226f67ad9843e04913ce4a97241ff4b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=1c7e71396e3cf2b5c2412b6831a84df389335292927a5a0cf24ba176b5d5fcf4
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built keybert sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers, keybert
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 0.3.0
#     Uninstalling sentence-transformers-0.3.0:
#       Successfully uninstalled sentence-transformers-0.3.0
# Successfully installed keybert-0.7.0 sentence-transformers-2.2.2 sentencepiece-0.1.99

# %%
pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.30.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %% [markdown]
# ## Imports

# %%
# general imports
import os
import math
import json
import scipy
from scipy import spatial
import zipfile
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn
from sklearn.manifold import TSNE

# %%
# keybert imports
import keybert
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer, util
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
# nltk/wordnet imports
import nltk
from nltk.corpus import brown
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer as ps
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# data
import yfinance as yf

# %% [markdown]
# # Tools

# %% [markdown]
# ## Sentence embeddings by SentenceTransformer

# %%
#from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L12-v2')
# Out:
# Downloading (…)5dded/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)4d81d5dded/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)81d5dded/config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)ded/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)5dded/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# Downloading (…)dded/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)4d81d5dded/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)1d5dded/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %% [markdown]
# ## KeyBERT

# %% [markdown]
# **Takes keywords from document level data**
#
# documentation: https://pypi.org/project/keybert/

# %%
#keybert_model = KeyBERT()
sentence_model = SentenceTransformer('sentence-transformers/all-MiniLM-L12-v2')
keybert_model = KeyBERT(model=sentence_model)

# %%
# keywords of ngram length: up to 1 word
#test_keywords = keybert_model.extract_keywords(test_text, keyphrase_ngram_range=(1, 1), stop_words=None)

# %%
#test_keywords

# %%
# ngram length: up to 2 words
#test_keywords_len2 = keybert_model.extract_keywords(test_text, keyphrase_ngram_range=(1, 2), stop_words=None)

# %%
#test_keywords_len2

# %% [markdown]
# ## NLTK: Wordnet, Lemmatizer and Stopwords

# %% [markdown]
# **Wordnet synset similarities**
#
# The wup_similarity method is short for Wu-Palmer Similarity, which is a scoring method based on how similar the word senses are and where the Synsets occur relative to each other in the hypernym tree.
#
#
# ---
#
#
#
# Example:
#
# score of "dog" and "cat" = 0.8571428571428571
#
# score of "digitization" and "digital" = 0.14285714285714285
#
# score of "digitization" and "technology" = 0.3
#
# ---
#
#
#
# Comment: Good for word sense comparison. High similarity scores mean that the words are synonyms or are typologically similar, does not concern their co-occurences in context in particular.

# %% [markdown]
# ### Initialise

# %%
lemmatizer = WordNetLemmatizer()

# %%
english_stopwords = set(stopwords.words('english'))

# %%
news_text = brown.words(categories='news')
fdist = nltk.FreqDist(w.lower() for w in news_text)

# %% [markdown]
# ## Sentiment Analysis Models

# %%
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-financial-news-sentiment-en")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
sa_roberta_en = AutoModelForSequenceClassification.from_pretrained("Jean-Baptiste/roberta-large-financial-news-sentiment-en")
sa_roberta = pipeline("sentiment-analysis", model="soleimanian/financial-roberta-large-sentiment")
en_pipe = pipeline("text-classification", model=sa_roberta_en, tokenizer=tokenizer)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/960 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/936 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %% [markdown]
# # Functions

# %% [markdown]
# ## Get Industry-ticker sets

# %%
'''
now_industry_df = get_industry_csv_df(now_industry_name, tickers_csv_base_path)
industry_tickers = list(now_industry_df["symbol"])
'''
# Out:
# '\nnow_industry_df = get_industry_csv_df(now_industry_name, tickers_csv_base_path)\nindustry_tickers = list(now_industry_df["symbol"])\n'

# %%
def get_industry_csv_df(industry_name, csv_base_path):
  now_path = csv_base_path + industry_name + ".csv"
  now_df = pd.read_csv(now_path)

  return now_df

# %%
def get_conventional_names(industry_df):
  conventional_name_dict = dict()

  for row in industry_df.iterrows():
    ticker = row[1]["symbol"]
    full_name = row[1]["company_name"]
    tokenized_name = word_tokenize(full_name)

    if tokenized_name[0].lower() not in english_stopwords:
      conventional_name_dict[ticker] = tokenized_name[0]
    else:
      counter = 1
      for id in range(counter, len(tokenized_name)):
        if tokenized_name[id].lower() not in english_stopwords:
          conventional_name_dict[ticker] = tokenized_name[id]
          break

  return conventional_name_dict

# %%
def get_tickers_from_raw_text(raw_text):
  tickers_list = list()

  token_raw = word_tokenize(raw_text)
  for token in token_raw:
    if token.isupper() == True:
      if token.isalpha() == True:
        if len(token) >= 2:
          tickers_list.append(token)
          #print(token)

  tickers_list = list(set(tickers_list))

  return tickers_list

# %% [markdown]
# ## Get Stock Price History Data

# %%
def get_prices_df(start, end, tickers):
  prices_df = pd.DataFrame()

  for ticker in tickers:
    ticker_yf = yf.Ticker(ticker)
    if prices_df.empty:
        prices_df = ticker_yf.history(start = start, end = end)
        prices_df['ticker']= ticker
    else:
        data_temp = ticker_yf.history(start = start, end = end)
        data_temp['ticker']= ticker
        prices_df = prices_df.append(data_temp)

  prices_df['ticker'] = prices_df['ticker'].replace({'META':'FB'})
  print(prices_df['ticker'].unique())

  return prices_df

# %% [markdown]
# ## Get Headlines by Industry

# %%
def date_to_num(date_string):
  date_num = int()
  date_list = date_string.split("-")

  year = int(date_list[0])
  month = int(date_list[1])
  day = int(date_list[2])

  date_num = 365*year + 12*month + day

  return date_num

# %%
def get_headlines_by_industry(all_headlines_df, industry_dict, target_industry_name, target_start, target_end):
  industry_news_list = list()
  start = date_to_num(target_start)
  end = date_to_num(target_end)

  for index, row in all_headlines_df.iterrows():
    if row["ticker"] in industry_dict[target_industry_name]:
      head_date = date_to_num(row["date"])

      if head_date > start and head_date < end:
        append_list = [row["ticker"], row["headline"], row["date"]]
        industry_news_list.append(append_list)

  return industry_news_list

# %% [markdown]
# ## Get Headlines by Company

# %%
def get_all_relevant_tickers(industry_tickers):
  all_tickers = list()

  for key, val in industry_tickers.items():
    #print(key, len(val))
    all_tickers += val
    #print("all tickers:", len(all_tickers))

  return all_tickers

# %%
def get_company_alt_name_list(ticker_name):
  # TODO: obtain conventional company name    eg. "Tesla" for ticker "TSLA"
  company_alt_name_list = list()
  company_alt_name_list.append(ticker_name)
  company_alt_name_list.append("alternative_name")

  return company_alt_name_list

# %%
def test_get_company_headlines(all_headlines_df, target_tickers, target_start, target_end):
  company_headlines = dict()
  start = date_to_num(target_start)
  end = date_to_num(target_end)

  for index, row in all_headlines_df.iterrows():

    for now_ticker in target_tickers:
      company_alt_name_list = get_company_alt_name_list(now_ticker)
      #heads = list()

      if row["ticker"] == now_ticker:
        head_date = date_to_num(row["date"])

        if head_date > start and head_date < end:
          append_list = [row["headline"], row["date"]]

          if now_ticker in company_headlines.keys():
            company_headlines[now_ticker].append(append_list)
          else:
            company_headlines[now_ticker] = [append_list]

    #print(now_ticker, len(heads))
    #company_headlines[now_ticker] = [company_alt_name_list, heads]

  return company_headlines

# %%
def og_get_company_headlines(all_headlines_df, target_tickers, target_start, target_end):
  company_headlines = dict()
  start = date_to_num(target_start)
  end = date_to_num(target_end)

  for now_ticker in target_tickers:
    company_alt_name_list = get_company_alt_name_list(now_ticker)
    heads = list()

    for index, row in all_headlines_df.iterrows():
      if row["ticker"] == now_ticker:
        head_date = date_to_num(row["date"])

        if head_date > start and head_date < end:
          append_list = [row["headline"], row["date"]]
          heads.append(append_list)

    print(now_ticker, len(heads))
    company_headlines[now_ticker] = [company_alt_name_list, heads]

  return company_headlines

# %% [markdown]
# ## Get Industry Sentiment

# %%
'''
news_text = brown.words(categories='news')
fdist = nltk.FreqDist(w.lower() for w in news_text)
modals = ['can', 'could', 'may', 'might', 'must', 'will']
for m in modals:
  print(m + ':', fdist[m], end=' ')
'''
# Out:
# "\nnews_text = brown.words(categories='news')\nfdist = nltk.FreqDist(w.lower() for w in news_text)\nmodals = ['can', 'could', 'may', 'might', 'must', 'will']\nfor m in modals:\n  print(m + ':', fdist[m], end=' ')\n"

# %%
def get_industry_info(industry_news, lemmatizer, company_alt_name_list):
  check_company_name = [x.lower() for x in company_alt_name_list.values()]
  kw_sentiment_dict = dict()
  kw_count_dict = dict()

  for id, head in enumerate(industry_news):
    filtered_keywords = list()
    keywords_raw = keybert_model.extract_keywords(head, keyphrase_ngram_range=(1,1), stop_words=None)
    #print("keywords_raw:", keywords_raw)

    for raw_kw in keywords_raw:
      if raw_kw[0].lower() not in check_company_name:
        kwsynset = wn.synsets(raw_kw[0])
        pos_res = nltk.pos_tag([raw_kw[0]])[0]
        if "NN" in pos_res[1]:
          if len(kwsynset) >= 1:
            kw_lemm = lemmatizer.lemmatize(raw_kw[0])
            if fdist[kw_lemm.lower()] <= 5:
              filtered_keywords.append(kw_lemm)
            #print("add:", raw_kw[0])

    #print("filtered keywords:", keywords)

    sentiment_result = sa_roberta(head)

    #print("result:", sentiment_result)

    #print("roberta-large-financial-news-sentiment-en\n", en_pipe(head))
    #print("financial-roberta-large-sentiment\n", sa_roberta(head))

    sentiment = sentiment_result[0]["label"]
    confidence = sentiment_result[0]["score"]
    #print("sentiment:", sentiment)
    #print("keywords", keywords, "\n")

    if sentiment == "neutral":
      sentiment_score = 0.0001 * confidence
    elif sentiment == "positive":
      sentiment_score = 1 * confidence
    elif sentiment == "negative":
      sentiment_score = -1 * confidence

    kw_sentiment_dict, kw_count_dict = get_keyword_dicts(filtered_keywords, kw_sentiment_dict, kw_count_dict, sentiment_score, lemmatizer)

  return kw_sentiment_dict, kw_count_dict

# %%
def get_industry_score(kw_sentiment_dict, kw_count_dict):

  if sum(list(kw_count_dict.values())) > 0:
    industry_score = sum(list(kw_sentiment_dict.values())) / sum(list(kw_count_dict.values()))
  else:
    industry_score = 0

  return industry_score

# %%
def get_keyword_dicts(keywords, kw_sentiment_dict, kw_count_dict, sentiment_score, lemmatizer):

  for kw in keywords:
    kw_lemm = lemmatizer.lemmatize(kw)
    if kw_lemm in kw_sentiment_dict:
      kw_sentiment_dict[kw_lemm] += sentiment_score
    else:
      kw_sentiment_dict[kw_lemm] = sentiment_score

    if kw_lemm in kw_count_dict:
      kw_count_dict[kw_lemm] += 1
    else:
      kw_count_dict[kw_lemm] = 1

  return kw_sentiment_dict, kw_count_dict

# %% [markdown]
# ## Get Company Sentiment

# %%
def get_company_subset(company_headlines, company_ticker, industry_keyword_list, company_name_skiplist):
  company_all_news_sentiment = dict()
  company_subset_sentiment = dict()

  if company_ticker in company_headlines.keys():
    company_all_news = company_headlines[company_ticker]
  else:
    company_all_news = []
  print(company_all_news)

  for head, date in company_all_news:
    #print("\n")
    #print("headline:", head)
    keywords = keybert_model.extract_keywords(head, keyphrase_ngram_range=(1,1), stop_words=None)
    sentiment_result = sa_roberta(head)

    #print("roberta-large-financial-news-sentiment-en\n", en_pipe(head))
    #print("financial-roberta-large-sentiment\n", sa_roberta(head))

    sentiment = sentiment_result[0]["label"]
    confidence = sentiment_result[0]["score"]
    #print("sentiment:", sentiment)
    #print("keywords", keywords)

    if sentiment == "neutral":
      sentiment_score = 0.0001 * confidence
    elif sentiment == "positive":
      sentiment_score = 1 * confidence
    elif sentiment == "negative":
      sentiment_score = -1 * confidence

    company_all_news_sentiment[head] = sentiment_score

    for kw, score in keywords:        # direct keyword matching here, can add glove embeddings related words as TODO later as well
      #print(kw, score)
      kw_lemm = lemmatizer.lemmatize(kw)
      if kw_lemm in industry_keyword_list: # when company news is related to industry news keywords

        if kw.lower() == company_ticker:
          if head not in company_subset_sentiment:
              company_subset_sentiment[head] = sentiment_score

        elif kw.lower() not in company_name_skiplist:
          #print("kw \"", kw, "\" in dict with sentiment score:", industry_keyword_list[kw])
          if head not in company_subset_sentiment:
            company_subset_sentiment[head] = sentiment_score

  return company_all_news_sentiment, company_subset_sentiment

# %% [markdown]
# # Run

# %% [markdown]
# ## Initialise

# %%
headlines_csv_df = pd.read_csv(headlines_csv_path)

# %%
# stays the same
industry_names = ["internet-content-and-information",
                  "entertainment",
                  "travel-services",
                  ]

# %%
# stays the same
industry_tickers = {"internet-content-and-information": [],
                    "entertainment": [],
                    "travel-services": [],
                    }

# %%
# changes with date range
industry_headlines = {"internet-content-and-information": [],
                      "entertainment": [],
                      "travel-services": [],
                      }

industry_company_sentiments = {"internet-content-and-information": [],
                               "entertainment": [],
                               "travel-services": [],
                               }

industry_sentiments = {"internet-content-and-information": [],
                        "entertainment": [],
                        "travel-services": [],
                        }

# %%
'''
# changes with date range
industry_company_sentiments = {"internet-content-and-information": [],
                               "entertainment": [],
                               "travel-services": [],
                               }
'''
# Out:
# '\n# changes with date range\nindustry_company_sentiments = {"internet-content-and-information": [],\n                               "entertainment": [],\n                               "travel-services": [],\n                               }\n'

# %%
'''
# changes with date range
industry_sentiments = {"internet-content-and-information": [],
                        "entertainment": [],
                        "travel-services": [],
                        }
'''
# Out:
# '\n# changes with date range\nindustry_sentiments = {"internet-content-and-information": [],\n                        "entertainment": [],\n                        "travel-services": [],\n                        }\n'

# %%
# run onces
for ind_name in industry_names:
  now_ind_df = get_industry_csv_df(ind_name, tickers_csv_base_path)
  industry_tickers[ind_name] = list(now_ind_df["symbol"])
  conventional_company_names = get_conventional_names(now_ind_df)

  print("conventional company names:", conventional_company_names)
# Out:
# conventional company names: {'GOOGL': 'Alphabet', 'META': 'Meta', 'BIDU': 'Baidu', 'SPOT': 'Spotify', 'DASH': 'DoorDash', 'SNAP': 'Snap', 'PINS': 'Pinterest', 'TME': 'Tencent', 'MTCH': 'Match', 'TWLO': 'Twilio', 'Z': 'Zillow', 'IAC': 'IAC', 'ATHM': 'Autohome', 'WB': 'Weibo', 'YELP': 'Yelp', 'CARG': 'CarGurus', 'YY': 'JOYY', 'GETY': 'Getty', 'MOMO': 'Hello', 'SSTK': 'Shutterstock', 'ANGI': 'Angi', 'OPRA': 'Opera', 'PERI': 'Perion', 'SEAT': 'Vivid', 'GENI': 'Genius', 'KIND': 'Nextdoor', 'FVRR': 'Fiverr', 'TBLA': 'Taboola.com', 'TTGT': 'TechTarget', 'MATH': 'Metalpha', 'THRY': 'Thryv', 'ZH': 'Zhihu', 'MAX': 'MediaAlpha', 'SMWB': 'Similarweb', 'TRVG': 'trivago', 'NN': 'NextNav', 'DOYU': 'DouYu', 'JFIN': 'Jiayin', 'OB': 'Outbrain', 'EVER': 'EverQuote', 'TRUE': 'TrueCar', 'GRPN': 'Groupon', 'LTRPA': 'Liberty', 'STBX': 'Starbox', 'BODY': 'Beachbody', 'SCOR': 'comScore', 'AREN': 'Arena', 'BZFD': 'BuzzFeed', 'EGLX': 'Enthusiast', 'CMCM': 'Cheetah', 'LIZI': 'Lizhi', 'UPXI': 'Upexi', 'IZEA': 'IZEA', 'FAZE': 'FaZe', 'KRKR': '36Kr', 'ASST': 'Asset', 'ZDGE': 'Zedge', 'FENG': 'Phoenix', 'LKCO': 'Luokung', 'SLGG': 'Super', 'TC': 'TuanChe', 'LOV': 'Spark', 'LCFY': 'Locafy', 'ONFO': 'Onfolio', 'GROM': 'Grom'}
# conventional company names: {'NFLX': 'Netflix', 'DIS': 'Walt', 'WBD': 'Warner', 'LYV': 'Live', 'FWONA': 'Formula', 'FOXA': 'Fox', 'SIRI': 'Sirius', 'WMG': 'Warner', 'NWSA': 'News', 'PARA': 'Paramount', 'ROKU': 'Roku', 'WWE': 'World', 'EDR': 'Endeavor', 'NXST': 'Nexstar', 'IQ': 'iQIYI', 'MSGS': 'Madison', 'MANU': 'Manchester', 'AMC': 'AMC', 'BATRK': 'Liberty', 'CNK': 'Cinemark', 'BOWL': 'Bowlero', 'LGF.A': 'Lions', 'PLAY': 'Dave', 'MSGE': 'Madison', 'SPHR': 'Sphere', 'IMAX': 'IMAX', 'HUYA': 'HUYA', 'SBGI': 'Sinclair', 'AMCX': 'AMC', 'MCS': 'Marcus', 'RSVR': 'Reservoir', 'LVO': 'LiveOne', 'GNUS': 'Genius', 'RDI': 'Reading', 'HOFV': 'Hall', 'GAIA': 'Gaia', 'MMV': 'MultiMetaVerse', 'AGAE': 'Allied', 'CSSE': 'Chicken', 'ANGH': 'Anghami', 'DLPN': 'Dolphin', 'BREA': 'Brera', 'KUKE': 'Kuke', 'CNVS': 'Cineverse', 'CPOP': 'Pop', 'ADD': 'Color'}
# conventional company names: {'BKNG': 'Booking', 'ABNB': 'Airbnb', 'RCL': 'Royal', 'TCOM': 'Trip.com', 'CCL': 'Carnival', 'EXPE': 'Expedia', 'NCLH': 'Norwegian', 'TNL': 'Travel', 'MMYT': 'MakeMyTrip', 'TRIP': 'Tripadvisor', 'SABR': 'Sabre', 'MOND': 'Mondee', 'LIND': 'Lindblad', 'DESP': 'Despegar.com', 'TOUR': 'Tuniu', 'YTRA': 'Yatra'}

# %%
# copied raw text of tickers by industries from https://stockanalysis.com/stocks/industry/

#raw_industry1_text = "1	GOOGL	Alphabet Inc.	1,531.88B -2.20% 8,215,944	284.61B 2	META	Meta Platforms, Inc.	719.72B -1.16% 4,826,119	117.35B 3	BIDU	Baidu, Inc.	49.60B -1.14% 626,785	18.40B 4	SPOT	Spotify Technology S.A.	29.85B -1.56% 933,574	13.16B 5	DASH	DoorDash, Inc.	28.18B -0.66% 611,516	7.16B 6	PINS	Pinterest, Inc.	16.93B -1.77% 2,149,388	2.83B 7	SNAP	Snap Inc.	16.43B -3.12% 4,483,302	4.53B 8	TME	Tencent Music Entertainment Group	13.15B 1.33% 1,718,368	4.18B 9	TWLO	Twilio Inc.	11.95B -3.19% 906,172	3.96B 10	MTCH	Match Group, Inc.	11.43B -3.25% 2,117,009	3.18B 11	Z	Zillow Group, Inc.	11.07B -0.54% 399,736	2.40B 12	IAC	IAC Inc.	5.24B 0.56% 130,638	4.99B 13	ATHM	Autohome Inc.	3.50B -0.66% 164,846	- 14	WB	Weibo Corporation	3.33B -1.43% 146,929	1.77B 15	CARG	CarGurus, Inc.	2.44B -2.51% 354,680	1.46B 16	YELP	Yelp Inc.	2.44B -2.80% 72,373	1.23B 17	YY	JOYY Inc.	2.07B 1.16% 298,531	329.88M 18	GETY	Getty Images Holdings, Inc.	2.01B -1.57% 194,886	930.91M 19	MOMO	Hello Group Inc.	1.79B 0.90% 318,003	12.37B 20	SSTK	Shutterstock, Inc.	1.73B -0.29% 97,955	843.97M 21	OPRA	Opera Limited	1.64B 1.73% 353,634	346.50M 22	ANGI	Angi Inc.	1.62B -0.77% 239,987	1.85B 23	PERI	Perion Network Ltd.	1.55B -1.78% 106,556	660.09M 24	SEAT	Vivid Seats Inc.	1.40B -2.05% 79,004	630.57M 25	GENI	Genius Sports Limited	1.20B 0.70% 233,265	352.34M 26	KIND	Nextdoor Holdings, Inc.	1.06B -2.59% 229,864	211.54M 27	FVRR	Fiverr International Ltd.	1.02B -3.27% 261,398	338.64M 28	TTGT	TechTarget, Inc.	931.55M -3.63% 30,401	286.44M 29	MATH	Metalpha Technology Holding Limited	901.37M	-	2,745	5.30M 30	THRY	Thryv Holdings, Inc.	883.48M -1.13% 33,105	1.14B 31	TBLA	Taboola.com Ltd.	853.64M -1.37% 202,674	1.37B 32	ZH	Zhihu Inc.	690.32M 2.40% 964,612	561.27M 33	MAX	MediaAlpha, Inc.	572.80M -0.62% 15,880	428.10M 34	SMWB	Similarweb Ltd.	521.32M -0.74% 9,741	201.70M 35	TRVG	trivago N.V.	399.08M -1.69% 269,821	591.74M 36	DOYU	DouYu International Holdings Limited	326.17M -0.98% 302,219	989.18M 37	JFIN	Jiayin Group Inc.	312.18M -8.44% 75,428	565.12M 38	NN	NextNav Inc.	297.30M -3.83% 62,107	3.56M 39	OB	Outbrain Inc.	246.55M -0.31% 18,489	969.64M 40	EVER	EverQuote, Inc.	222.01M -3.86% 76,951	402.67M 41	TRUE	TrueCar, Inc.	185.98M -3.70% 59,551	154.97M 42	LTRPA	Liberty TripAdvisor Holdings, Inc.	179.53M 1.04% 4,515	1.60B 43	STBX	Starbox Group Holdings Ltd.	163.13M -0.99% 25,877	7.19M 44	BODY	The Beachbody Company, Inc.	152.85M 0.43% 272,678	638.18M 45	GRPN	Groupon, Inc.	135.18M 2.58% 330,935	567.38M 46	BZFD	BuzzFeed, Inc.	88.55M -4.10% 303,112	412.27M 47	SCOR	comScore, Inc.	81.34M -1.72% 11,692	374.02M 48	AREN	The Arena Group Holdings, Inc.	79.42M 2.29% 5,270	224.07M 49	CMCM	Cheetah Mobile Inc.	68.76M 1.42% 9,905	126.84M 50	EGLX	Enthusiast Gaming Holdings Inc.	68.30M -1.41% 30,347	143.88M 51	LIZI	Lizhi Inc.	49.79M -2.65% 173,962	334.72M 52	UPXI	Upexi, Inc.	40.98M 3.72% 28,985	78.06M 53	IZEA	IZEA Worldwide, Inc.	40.43M -4.49% 13,436	40.94M 54	FAZE	FaZe Holdings Inc.	35.30M 0.21% 27,900	66.77M 55	KRKR	36Kr Holdings Inc.	33.41M 2.25% 20,384	47.80M 56	ZDGE	Zedge, Inc.	31.54M 1.89% 10,467	27.98M 57	ASST	Asset Entities Inc.	25.68M -6.90% 194,059	278.18K 58	FENG	Phoenix New Media Limited	24.51M -3.35% 5,265	110.14M 59	LOV	Spark Networks SE	20.73M -0.01% 14,824	195.55M 60	LKCO	Luokung Technology Corp.	19.79M -1.57% 39,600	93.59M 61	SLGG	Super League Gaming, Inc.	17.39M -7.56% 1,128,511	19.23M 62	TC	TuanChe Limited	13.28M 3.41% 5,659	26.28M 63	LCFY	Locafy Limited	7.27M	-	1	- 64	ONFO	Onfolio Holdings, Inc.	6.29M -2.36% 20,833	3.19M 65	GROM	Grom Social Enterprises, Inc.	3.07M 0.08% 79,583	5.40M"
#raw_industry2_text = "1	NFLX	Netflix, Inc.	191.53B -0.89% 1,183,261	31.91B 2	DIS	The Walt Disney Company	162.32B -1.05% 4,454,386	86.98B 3	WBD	Warner Bros. Discovery, Inc.	29.81B 0.37% 4,136,713	41.36B 4	LYV	Live Nation Entertainment, Inc.	20.45B -0.25% 133,282	18.01B 5	FWONA	Formula One Group	18.02B 0.79% 11,787	12.15B 6	FOXA	Fox Corporation	16.32B 0.24% 553,802	14.91B 7	SIRI	Sirius XM Holdings Inc.	14.43B -0.27% 2,214,063	8.96B 8	WMG	Warner Music Group Corp.	13.54B -0.98% 138,267	5.82B 9	NWSA	News Corporation	11.02B 0.39% 239,630	10.12B 10	PARA	Paramount Global	10.39B 0.70% 3,067,447	30.09B 11	ROKU	Roku, Inc.	9.36B -2.30% 1,327,813	3.13B 12	WWE	World Wrestling Entertainment, Inc.	7.53B 0.11% 74,162	1.26B 13	EDR	Endeavor Group Holdings, Inc.	6.68B 0.77% 269,294	5.39B 14	NXST	Nexstar Media Group, Inc.	5.84B 0.22% 42,531	5.26B 15	IQ	iQIYI, Inc.	5.09B 0.38% 2,076,703	4.38B 16	MSGS	Madison Square Garden Sports Corp.	4.21B 0.40% 11,015	935.73M 17	AMC	AMC Entertainment Holdings, Inc.	4.08B 0.11% 3,728,723	4.08B 18	MANU	Manchester United plc	3.76B 2.51% 344,834	701.59M 19	BOWL	Bowlero Corp.	2.02B 2.64% 751,343	1.09B 20	CNK	Cinemark Holdings, Inc.	2.00B 0.18% 357,207	2.60B 21	LGF.A	Lions Gate Entertainment Corp.	2.00B -1.14% 53,107	3.85B 22	MSGE	Madison Square Garden Entertainment Corp.	1.87B -9.02% 207,752	- 23	PLAY	Dave & Buster's Entertainment, Inc.	1.80B -0.17% 245,094	2.11B 24	IMAX	IMAX Corporation	952.59M 0.17% 55,594	327.72M 25	SPHR	Sphere Entertainment Co.	947.70M -2.29% 125,361	1.86B 26	HUYA	HUYA Inc.	921.22M 2.13% 848,324	1.27B 27	SBGI	Sinclair Broadcast Group, Inc.	813.83M -1.26% 163,849	3.41B 28	MCS	The Marcus Corporation	465.12M -0.27% 24,135	697.43M 29	AMCX	AMC Networks Inc.	461.58M -0.75% 76,246	3.10B 30	RSVR	Reservoir Media, Inc.	395.62M 2.17% 71,286	122.29M 31	LVO	LiveOne, Inc.	136.75M -1.26% 74,908	97.50M 32	GNUS	Genius Brands International, Inc.	95.87M -1.48% 121,662	75.05M 33	RDI	Reading International, Inc.	93.67M 0.76% 4,565	208.72M 34	HOFV	Hall of Fame Resort & Entertainment Company	56.23M 7.50% 22,840	16.99M 35	GAIA	Gaia, Inc.	51.76M 2.06% 204	79.85M 36	MMV	MultiMetaVerse Holdings Limited	45.49M -4.79% 75,144	12.23M 37	AGAE	Allied Gaming & Entertainment Inc.	40.39M	-	3,006	5.13M 38	CSSE	Chicken Soup for the Soul Entertainment, Inc.	35.04M -2.44% 68,074	333.20M 39	ANGH	Anghami Inc.	27.83M 0.94% 25,716	48.48M 40	DLPN	Dolphin Entertainment, Inc.	25.46M -2.21% 2,917	41.22M 41	BREA	Brera Holdings PLC	22.35M -1.28% 2,707	172.77K 42	CNVS	Cineverse Corp.	20.03M 1.40% 51,301	72.33M 43	KUKE	Kuke Music Holding Limited	17.75M -13.15% 26,542	16.52M 44	ADD	Color Star Technology Co., Ltd.	12.73M 1.14% 7,769	7.09M 45	CPOP"
#raw_industry3_text = "1	BKNG	Booking Holdings Inc.	96.85B -0.59% 48,631	18.17B 2	ABNB	Airbnb, Inc.	79.24B -0.62% 1,149,329	8.71B 3	RCL	Royal Caribbean Cruises Ltd.	24.59B -0.29% 816,217	10.67B 4	TCOM	Trip.com Group Limited	22.66B 1.01% 956,415	3.66B 5	CCL	Carnival Corporation & plc	20.44B -1.29% 11,066,307	14.98B 6	EXPE	Expedia Group, Inc.	15.60B -1.48% 465,782	12.08B 7	NCLH	Norwegian Cruise Line Holdings Ltd.	8.12B -0.75% 2,453,274	6.14B 8	TNL	Travel + Leisure Co.	3.08B -0.57% 69,998	3.64B 9	MMYT	MakeMyTrip Limited	2.86B 0.97% 28,411	593.04M 10	TRIP	Tripadvisor, Inc.	2.30B -2.09% 383,123	1.60B 11	SABR	Sabre Corporation	1.05B -4.38% 2,218,515	2.69B 12	MOND	Mondee Holdings, Inc.	750.89M 1.72% 27,435	171.76M 13	LIND	Lindblad Expeditions Holdings, Inc.	550.09M -0.39% 29,659	497.05M 14	DESP	Despegar.com, Corp.	469.00M -0.42% 23,522	584.27M 15	TOUR	Tuniu Corporation	206.76M -0.60% 44,577	29.89M 16	YTRA	Yatra Online, Inc.	134.79M 3.37% 31,838	46.56M Stock Analysis Pro Unlimited access to all our financial data with up to 30 years of history. Stock Screener Filter, sort and analyze all stocks to find your next investment. Watchlists Keep track of your favorite stocks in real-time. Market Newsletter Market-moving news and events each morning in short, bullet-point format."

#industry_tickers["Internet Content & Information"] = get_tickers(raw_industry1_text)
#industry_tickers["Entertainment"] = get_tickers(raw_industry2_text)
#industry_tickers["Travel Services"] = get_tickers(raw_industry3_text)

# %% [markdown]
# ## Get json content

# %% [markdown]
# ### Functions

# %%
def update_date(date):
  year = date.split("-")[0]
  month = date.split("-")[1]
  day = date.split("-")[2]

  if month == "12":
    new_month = "01"
    new_year = str(int(year) + 1)
  else:
    new_year = year
    new_month = int(month) + 1
    if new_month < 10:
      new_month = "0" + str(new_month)

  new_date = new_year + "-" + str(new_month) + "-" + day

  return new_date

# %%
def get_json_content_industry_sentiment(headlines_df, industry_headlines, industry_tickers_dict, start_date, end_date):
  json_content_dict = dict()

  # Get headlines given industry and target period
  for key in industry_headlines.keys():
    industry_headlines[key] = get_headlines_by_industry(headlines_df, industry_tickers_dict, key, start_date, end_date)

  all_target_tickers = get_all_relevant_tickers(industry_tickers_dict)
  company_headlines_dict = test_get_company_headlines(headlines_df, all_target_tickers, start_date, end_date)

  # Industry sentiments
  for industry in industry_sentiments.keys():
    print("----------------------------------------------------------")
    print("industry:", industry)
    print(industry_headlines[industry])
    ind_head = [item[1] for item in industry_headlines[industry]]

    # I use 200 entries for testing
    ind_head = ind_head #[:200]

    print("ind head:", len(ind_head))

    ind_kw_sentiment_dict, ind_kw_count_dict = get_industry_info(ind_head, lemmatizer, conventional_company_names)
    print(ind_kw_sentiment_dict)
    ind_sentiment = get_industry_score(ind_kw_sentiment_dict, ind_kw_count_dict)

    print("sentiment dict:", len(ind_kw_sentiment_dict), "keyword count:", len(ind_kw_count_dict))
    print("industry score:", ind_sentiment)

    industry_sentiments[industry] = [ind_sentiment, ind_kw_sentiment_dict, ind_kw_count_dict]

    json_content_dict[industry] = {"start": start_date,
                                   "end": end_date,
                                   "sentiment": ind_sentiment}

  return json_content_dict

# %%
def get_json_content_company_sentiment(industry_tickers_dict, conventional_company_names_dict, company_headlines_dict, industry_sentiments_dict, start_date, end_date):
  json_content_dict = dict()

  #####################################3
  # Company final sentiments
  for industry in industry_tickers_dict.keys():
    target_tickers_list = industry_tickers_dict[industry]
    #now_industry_sentiment = industry_sentiments_dict[industry][0]
    now_industry_company_sentiment = dict()

    #print("Industry:", industry)
    #print("Industry sentiment:", now_industry_sentiment)

    for now_ticker in target_tickers_list:
      print("company:", now_ticker)
      company_name_skip_list = []

      for key, val in conventional_company_names_dict.items():
        if key != now_ticker:
          company_name_skip_list.append(val)

      now_company_allnews_sent, now_company_subset_sent = get_company_subset(company_headlines_dict, now_ticker, industry_sentiments_dict[industry][1], company_name_skip_list)

      if len(now_company_allnews_sent) >= 1:
        now_company_allnews_score = sum(list(now_company_allnews_sent.values())) / len(now_company_allnews_sent)
      else:
        now_company_allnews_score = 0

      if len(now_company_subset_sent) >= 1:
        now_company_subset_score = sum(list(now_company_subset_sent.values())) / len(now_company_subset_sent)
      else:
        now_company_subset_score = 0

      print("company_allnews_sentiment:", now_company_allnews_sent)
      print("company_subset_sentiment:", now_company_subset_sent)

      print("company score (all news concerned):", now_company_allnews_score)
      print("company score (as influenced by industry):", now_company_subset_score)

      ###################################

      now_company_rel_score = (now_company_allnews_score + now_company_subset_score) / 2

      json_content_dict[now_ticker] = {"start": start_date,
                                       "end": end_date,
                                       "sentiment": now_company_rel_score}

      #now_company_final_score = now_industry_sentiment + now_company_rel_score
      #now_industry_company_sentiment[now_ticker] = now_company_final_score

      #print("company relevant [(now_company_allnews_score + now_company_subset_score) /2]: ", now_company_rel_score)
      #print("company final score: (industry_sentiment + now_company_rel_score)", now_company_final_score)

    #industry_company_sentiments[industry] = now_industry_company_sentiment

  #####################################

  return json_content_dict

# %% [markdown]
# ### Run

# %%
# full target period for json output
period_start = "2012-01-01"
period_end = "2013-01-31"

# dates to be updated
date_start = "2012-01-01"   # YYYY-MM-DD
date_end = "2012-01-31"     # YYYY-MM-DD
process_date = [date_start, date_end]

json_industry = dict()
json_company = dict()

# %%
for name in industry_names:
  json_industry[name] = list()

# %%
json_industry
# Out:
# {'internet-content-and-information': [],
#  'entertainment': [],
#  'travel-services': []}

# %%
json_company
# Out:
# {}

# %%
while date_end != period_end:
  print("start:", date_start, "end:", date_end)

  # changes with date range
  industry_headlines = {"internet-content-and-information": [],
                        "entertainment": [],
                        "travel-services": [],
                        }

  industry_company_sentiments = {"internet-content-and-information": [],
                                "entertainment": [],
                                "travel-services": [],
                                }

  industry_sentiments = {"internet-content-and-information": [],
                          "entertainment": [],
                          "travel-services": [],
                          }

  all_target_tickers = get_all_relevant_tickers(industry_tickers)
  #print(len(all_target_tickers))
  #print(all_target_tickers[:5])
  company_headlines_dict = test_get_company_headlines(headlines_csv_df, all_target_tickers, date_start, date_end)

  now_json_industry_content_dict = get_json_content_industry_sentiment(headlines_csv_df, industry_headlines, industry_tickers, date_start, date_end)
  now_json_company_content_dict = get_json_content_company_sentiment(industry_tickers, conventional_company_names, company_headlines_dict,
                                                                     industry_sentiments, date_start, date_end)

  for key, item in now_json_industry_content_dict.items():
    #print(key, item)
    if len(json_industry[key]) < 1:
      json_industry[key] = [item]
    else:
      #print("else")
      #print(json_industry[key])
      existing_content = json_industry[key]
      #print(type(existing_content), existing_content)
      new_content = [item]
      json_industry[key] = existing_content + new_content


  for key, item in now_json_company_content_dict.items():
    if key in json_company.keys():
      if len(json_company[key]) < 1:
        json_company[key] = [item]
      else:
        existing_content = json_company[key]
        if type(existing_content) != list:
          existing_content = [existing_content]
        new_content = [item]
        json_company[key] = existing_content + new_content
    else:
      json_company[key] = item


  #print("updated json industry output:")
  #print(json_industry)

  # update dates for next run
  date_start = update_date(date_start)
  date_end = update_date(date_end)
  process_date = [date_start, date_end]
# Out:
# Streaming output truncated to the last 5000 lines.
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: NXST
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: IQ
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MSGS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MANU
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: AMC
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BATRK
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CNK
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BOWL
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: LGF.A
# [['More on Lions Gate Entertainment (LGF): FQ4 swings to a loss on higher marketing and acquisition costs from its January acquisition of Summit Entertainment. Revenue surged 71% Y/Y on "The Hunger Games" box office receipts, as well as home entertainment sales of "The Twilight Saga: Breaking Dawn: Part 1.." Shares -5% AH.', '2012-05-30'], ['Lions Gate Entertainment (LGF): FQ4 EPS of -$0.17 may not be comparable to consensus of $0.27. Revenue of $645.2M (+71% Y/Y) beats by $27M. Shares -3% AH. (PR)', '2012-05-30'], ['Execs with Lions Gate (LGF +1.3%) say on a CC that 90% of the profit for The Hunger Games still lies ahead for the company. Shares of LGF have started to move up during the course of the call after sitting in negative territory premarket. (webcast)', '2012-05-31'], ["Shares of Lions Gate (LGF +1.9%) gain ground with news out that the company will release a digitally-remastered version of the second movie in the Hunger Games series for IMAX release in November of 2013. Instead of simply blowing up the movie for the larger screen format, part of it will be filmed utilizing special 3D cameras which may add to the buzz a bit as it's released.", '2012-06-13']]
# company_allnews_sentiment: {'More on Lions Gate Entertainment (LGF): FQ4 swings to a loss on higher marketing and acquisition costs from its January acquisition of Summit Entertainment. Revenue surged 71% Y/Y on "The Hunger Games" box office receipts, as well as home entertainment sales of "The Twilight Saga: Breaking Dawn: Part 1.." Shares -5% AH.': -0.9920010566711426, 'Lions Gate Entertainment (LGF): FQ4 EPS of -$0.17 may not be comparable to consensus of $0.27. Revenue of $645.2M (+71% Y/Y) beats by $27M. Shares -3% AH. (PR)': 0.9953674077987671, 'Execs with Lions Gate (LGF +1.3%) say on a CC that 90% of the profit for The Hunger Games still lies ahead for the company. Shares of LGF have started to move up during the course of the call after sitting in negative territory premarket. (webcast)': 0.995262622833252, "Shares of Lions Gate (LGF +1.9%) gain ground with news out that the company will release a digitally-remastered version of the second movie in the Hunger Games series for IMAX release in November of 2013. Instead of simply blowing up the movie for the larger screen format, part of it will be filmed utilizing special 3D cameras which may add to the buzz a bit as it's released.": 0.9979021549224854}
# company_subset_sentiment: {'Execs with Lions Gate (LGF +1.3%) say on a CC that 90% of the profit for The Hunger Games still lies ahead for the company. Shares of LGF have started to move up during the course of the call after sitting in negative territory premarket. (webcast)': 0.995262622833252, "Shares of Lions Gate (LGF +1.9%) gain ground with news out that the company will release a digitally-remastered version of the second movie in the Hunger Games series for IMAX release in November of 2013. Instead of simply blowing up the movie for the larger screen format, part of it will be filmed utilizing special 3D cameras which may add to the buzz a bit as it's released.": 0.9979021549224854}
# company score (all news concerned): 0.49913278222084045
# company score (as influenced by industry): 0.9965823888778687
# company: PLAY
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MSGE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: SPHR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: IMAX
# [['Shares of IMAX gain 4.7% in early trading as investors jump into the company as it maintains an aggressive global growth track with China a big target. This week sees the opening of The Dark Knight Rises, notable for its significant amount of footage shot with IMAX cameras. Director Christopher Nolan is an outspoken proponent that the IMAX format - not 3D - is the future of cinema.', '2012-07-17']]
# company_allnews_sentiment: {'Shares of IMAX gain 4.7% in early trading as investors jump into the company as it maintains an aggressive global growth track with China a big target. This week sees the opening of The Dark Knight Rises, notable for its significant amount of footage shot with IMAX cameras. Director Christopher Nolan is an outspoken proponent that the IMAX format - not 3D - is the future of cinema.': 0.998191773891449}
# company_subset_sentiment: {'Shares of IMAX gain 4.7% in early trading as investors jump into the company as it maintains an aggressive global growth track with China a big target. This week sees the opening of The Dark Knight Rises, notable for its significant amount of footage shot with IMAX cameras. Director Christopher Nolan is an outspoken proponent that the IMAX format - not 3D - is the future of cinema.': 0.998191773891449}
# company score (all news concerned): 0.998191773891449
# company score (as influenced by industry): 0.998191773891449
# company: HUYA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: SBGI
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: AMCX
# [['Shares of AMC Networks (AMCX +0.1%) trade flat after Dish Networks (DISH +2.9%) calls its bluff and says it will drop three of its channels from its lineup of programming tonight. On the other side of the coin, Dish is airing its own commercial-free programming on the trio of networks and will take a bit of a revenue hit as it gambles that it will gain it all back and more if it secures a lower fee structure from AMC in the future.', '2012-06-29']]
# company_allnews_sentiment: {'Shares of AMC Networks (AMCX +0.1%) trade flat after Dish Networks (DISH +2.9%) calls its bluff and says it will drop three of its channels from its lineup of programming tonight. On the other side of the coin, Dish is airing its own commercial-free programming on the trio of networks and will take a bit of a revenue hit as it gambles that it will gain it all back and more if it secures a lower fee structure from AMC in the future.': -0.9978086352348328}
# company_subset_sentiment: {'Shares of AMC Networks (AMCX +0.1%) trade flat after Dish Networks (DISH +2.9%) calls its bluff and says it will drop three of its channels from its lineup of programming tonight. On the other side of the coin, Dish is airing its own commercial-free programming on the trio of networks and will take a bit of a revenue hit as it gambles that it will gain it all back and more if it secures a lower fee structure from AMC in the future.': -0.9978086352348328}
# company score (all news concerned): -0.9978086352348328
# company score (as influenced by industry): -0.9978086352348328
# company: MCS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: RSVR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: LVO
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: GNUS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: RDI
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: HOFV
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: GAIA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MMV
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: AGAE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CSSE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: ANGH
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: DLPN
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BREA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: KUKE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CNVS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CPOP
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: ADD
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BKNG
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: ABNB
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: RCL
# [['Nomura raises Q2 profit estimates for Royal Carribean (NYSE:RCL) and Carnival (NYSE:CCL) with lower fuel prices on the horizon. Analyst Harry Curtis also moves to a more positive outlook for long-term pricing, with the fallout from the Costa Concordia sinking diminishing after Q3. Premarket: CCL +1.5%, RCL +1.4%.', '2012-06-07']]
# company_allnews_sentiment: {'Nomura raises Q2 profit estimates for Royal Carribean (NYSE:RCL) and Carnival (NYSE:CCL) with lower fuel prices on the horizon. Analyst Harry Curtis also moves to a more positive outlook for long-term pricing, with the fallout from the Costa Concordia sinking diminishing after Q3. Premarket: CCL +1.5%, RCL +1.4%.': 0.9979165196418762}
# company_subset_sentiment: {'Nomura raises Q2 profit estimates for Royal Carribean (NYSE:RCL) and Carnival (NYSE:CCL) with lower fuel prices on the horizon. Analyst Harry Curtis also moves to a more positive outlook for long-term pricing, with the fallout from the Costa Concordia sinking diminishing after Q3. Premarket: CCL +1.5%, RCL +1.4%.': 0.9979165196418762}
# company score (all news concerned): 0.9979165196418762
# company score (as influenced by industry): 0.9979165196418762
# company: TCOM
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CCL
# [['Carnival (NYSE:CCL): FQ2 EPS of $0.20 beats by $0.13. Revenue of $3.5B (-2.2%% Y/Y) misses by $50M. Shares +1.8% premarket. (PR)', '2012-06-22']]
# company_allnews_sentiment: {'Carnival (NYSE:CCL): FQ2 EPS of $0.20 beats by $0.13. Revenue of $3.5B (-2.2%% Y/Y) misses by $50M. Shares +1.8% premarket. (PR)': 0.9954895377159119}
# company_subset_sentiment: {}
# company score (all news concerned): 0.9954895377159119
# company score (as influenced by industry): 0
# company: EXPE
# [["More on Expedia's Q1: Strong results fueled by 24% Y/Y increase in room nights (37% for Hotels.com), up from 19% in Q4. Hotel revenue (70% of total) +17%, offsetting a 17% drop in plane ticket revenue (11% of total) due to lower prices. All other revenue sources (car rentals, ads, etc. ) +15%. $291M worth of shares repurchased. EXPE +16.5% AH. PCLN +0.8%. TZOO +1.7%. TRIP +2.2%. (PR - PDF)", '2012-04-26'], ['Expedia (EXPE +29%) is off to the races following its huge Q1 beat, driven by strong hotel bookings, and is lifting other online travel firms in the process: PCLN +3.8%. OWW +9.1%. TRIP +7.7%. TZOO +3.6%. JPMorgan is upgrading Expedia in response, while Deutsche (Hold) thinks management\'s reiteration of its 2012 EBITDA forecast is "conservative in light of building momentum." Benchmark (Hold) agrees, though it expects growth to decelerate in Q2. (transcript)', '2012-04-27'], ['Premarket gainers: EXPE +19%. AMZN +17%. JAZZ +15%. CRAY +12%. WCRX +12%. BPZ +6%. CBS +5%. AEM +5%. RTK +5%. ARNA +4%. GT +4%. CLWR +3%. SNY +3%. MT +3%. ARMH +3%.Losers: MDRX -42%. DECK -19%. WDC -11%. STX -7%. KOG -5%. SBUX -4%. FIO -4%.', '2012-04-27'], ['Online travel stocks take a beating, with Expedia (EXPE -4.2%), Priceline.com (PCLN -1.9%, Orbitz Worldwide (OWW -8.7%), and Tripadvisor (TRIP -4.4%) all underperforming market indexes. Though shares of Ctrip.com (CTRP +8.1%) are downright giddy following a pair of analyst upgrades, the broader theme from the analyst coverage paints a picture of intense competition and shrinking margins in the sector.', '2012-05-17']]
# company_allnews_sentiment: {"More on Expedia's Q1: Strong results fueled by 24% Y/Y increase in room nights (37% for Hotels.com), up from 19% in Q4. Hotel revenue (70% of total) +17%, offsetting a 17% drop in plane ticket revenue (11% of total) due to lower prices. All other revenue sources (car rentals, ads, etc. ) +15%. $291M worth of shares repurchased. EXPE +16.5% AH. PCLN +0.8%. TZOO +1.7%. TRIP +2.2%. (PR - PDF)": 0.9981538653373718, 'Expedia (EXPE +29%) is off to the races following its huge Q1 beat, driven by strong hotel bookings, and is lifting other online travel firms in the process: PCLN +3.8%. OWW +9.1%. TRIP +7.7%. TZOO +3.6%. JPMorgan is upgrading Expedia in response, while Deutsche (Hold) thinks management\'s reiteration of its 2012 EBITDA forecast is "conservative in light of building momentum." Benchmark (Hold) agrees, though it expects growth to decelerate in Q2. (transcript)': 0.9980432987213135, 'Premarket gainers: EXPE +19%. AMZN +17%. JAZZ +15%. CRAY +12%. WCRX +12%. BPZ +6%. CBS +5%. AEM +5%. RTK +5%. ARNA +4%. GT +4%. CLWR +3%. SNY +3%. MT +3%. ARMH +3%.Losers: MDRX -42%. DECK -19%. WDC -11%. STX -7%. KOG -5%. SBUX -4%. FIO -4%.': 0.9972478747367859, 'Online travel stocks take a beating, with Expedia (EXPE -4.2%), Priceline.com (PCLN -1.9%, Orbitz Worldwide (OWW -8.7%), and Tripadvisor (TRIP -4.4%) all underperforming market indexes. Though shares of Ctrip.com (CTRP +8.1%) are downright giddy following a pair of analyst upgrades, the broader theme from the analyst coverage paints a picture of intense competition and shrinking margins in the sector.': -0.9989535808563232}
# company_subset_sentiment: {'Expedia (EXPE +29%) is off to the races following its huge Q1 beat, driven by strong hotel bookings, and is lifting other online travel firms in the process: PCLN +3.8%. OWW +9.1%. TRIP +7.7%. TZOO +3.6%. JPMorgan is upgrading Expedia in response, while Deutsche (Hold) thinks management\'s reiteration of its 2012 EBITDA forecast is "conservative in light of building momentum." Benchmark (Hold) agrees, though it expects growth to decelerate in Q2. (transcript)': 0.9980432987213135, 'Premarket gainers: EXPE +19%. AMZN +17%. JAZZ +15%. CRAY +12%. WCRX +12%. BPZ +6%. CBS +5%. AEM +5%. RTK +5%. ARNA +4%. GT +4%. CLWR +3%. SNY +3%. MT +3%. ARMH +3%.Losers: MDRX -42%. DECK -19%. WDC -11%. STX -7%. KOG -5%. SBUX -4%. FIO -4%.': 0.9972478747367859}
# company score (all news concerned): 0.498622864484787
# company score (as influenced by industry): 0.9976455867290497
# company: NCLH
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TNL
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MMYT
# [['MakeMyTrip Limited (NASDAQ:MMYT): FQ4 EPS of $0.08 beats by $0.02. Revenue of $47M (+66.8% Y/Y) beats by $16M. Shares +5.4% premarket. (PR)', '2012-05-24']]
# company_allnews_sentiment: {'MakeMyTrip Limited (NASDAQ:MMYT): FQ4 EPS of $0.08 beats by $0.02. Revenue of $47M (+66.8% Y/Y) beats by $16M. Shares +5.4% premarket. (PR)': 0.9979153275489807}
# company_subset_sentiment: {'MakeMyTrip Limited (NASDAQ:MMYT): FQ4 EPS of $0.08 beats by $0.02. Revenue of $47M (+66.8% Y/Y) beats by $16M. Shares +5.4% premarket. (PR)': 0.9979153275489807}
# company score (all news concerned): 0.9979153275489807
# company score (as influenced by industry): 0.9979153275489807
# company: TRIP
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: SABR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MOND
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: LIND
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: DESP
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TOUR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: YTRA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# start: 2012-07-01 end: 2012-07-31
# ----------------------------------------------------------
# industry: internet-content-and-information
# [['YELP', "Yelp (YELP -3.7%) is joining in on a general selloff in high-beta Internet and social networking names; shares are now down 25% since the day of Facebook's IPO, and are closing in on the company's IPO price of $15. Google's (NASDAQ:GOOG) recent overhaul of its local commerce content, which includes the arrival of free Zagat reviews, could also be weighing on shares.", '2012-05-31'], ['Z', "Zillow (Z +5.8%) jumps on an upgrade to Outperform from Pac Crest. A full 50.1% of the company's float was shorted as of May 31, but Steven Cohen's SAC Capital has been a buyer.", '2012-06-14'], ['GRPN', "Groupon (GRPN -3.7%) sells off towards its post-IPO lows after Ascendant Capital slashes its 2012 EPS estimate and lowers its PT to $8. The firm is worried about forex issues (i.e. a weak euro), and also airs concerns about higher refund reserves, an issue that took center stage in the company's Q4 restatement.", '2012-06-14'], ['GRPN', 'Groupon (NASDAQ:GRPN) +4.4% on an upgrade to Overweight from Morgan Stanley. The firm, which is setting a PT of $18, cites a lower valuation, and thinks rivals such as Google Offers, AmazonLocal, and LivingSocial have "not gained meaningful traction or deployed new innovations." Groupon rallied on Friday along with other recently-battered Internet names. (also)', '2012-06-18'], ['BODY', 'Body Central (OTCQB:BODY) says that it expects Q2 EPS to come in at $0.19-$0.21, a mark that falls short of the consensus estimate of analysts that calls for $0.27. The company cites continued soft comparable store sales and the need for it to aggressively markdown slow moving items as factors in sharply reducing its guidance. Shares -24.9% premarket.', '2012-06-18'], ['GRPN', "Groupon (GRPN -10.5%) chairman and co-founder Eric Lefkofsky discloses on his blog he will be assuming a reduced role at the daily deals giant, and will spend more time working with VC firm Lightbank. That, in addition to Susquehanna's note, likely contributed to Groupon's selloff today, particularly given the Street's lingering concerns about CEO Andrew Mason.", '2012-07-02'], ['GRPN', 'Groupon (GRPN -6.8%) dives below $10 once again after Susquehannna (Neutral) lowers its PT to $12 from $15, citing worries about higher marketing expenses (ed: their decline in Q1 helped fuel Groupon\'s post-earnings rally) and Groupon\'s "take rate" (its daily deals revenue split with merchants).', '2012-07-02'], ['GRPN', "Groupon (GRPN -7.6%) fell hard for the second straight day as the Street digests chairman Eric Lefkofsky's plans to take a reduced role, thus leaving controversial CEO Andrew Mason more firmly in control. Bulls looking for a bit of good news might want to check out a comScore study that suggests Groupon is proving popular with European women: it estimates over 14M visited Groupon's site in May.", '2012-07-03'], ['YELP', "Yelp (YELP +7.6%) soars to levels last seen in early April, as speculation grows that Apple plans to integrate Yelp's check-in feature for points of interest within its new mapping software (previous), which will accompany iOS 6. There's no word on whether Foursquare or Facebook's (NASDAQ:FB) check-in features will also be integrated.", '2012-07-05'], ['GRPN', "Groupon (GRPN -5.9%) dives below $8 for the first time after Citi's Mark Mahaney cuts his estimates on concerns about European sales, which account for 25% of Groupon's revenue. Mahaney now expects Groupon to post 2013 EBITDA of $718M, down from a prior $930M. The company's Q2 report is expected to arrive around month's end. (previous)", '2012-07-11'], ['GRPN', "Groupon (GRPN -3.4%) continues to have an ugly July - shares are now down 28% from the beginning of the month. Worries about leadership, marketing spend, and Euro exposure all seem to be taking a toll ahead of the company's Q2 report, expected near the end of the month.", '2012-07-12'], ['BIDU', "Chinese Internet stocks, many of whom fell yesterday on worries about the Middle Kingdom's growth outlook, are ...
# ind head: 36
# {'selloff': -0.9988855719566345, 'yelp': 3.9908170104026794, 'ipo': -1.996271550655365, 'crest': 0.9978571534156799, 'buyer': 0.9978571534156799, 'pac': 0.9978571534156799, 'pt': -1.9976363778114319, 'nasdaq': 1.5281010270118713, 'valuation': 0.9974913597106934, 'estimate': -0.9989566802978516, 'role': -0.9932831525802612, 'decline': -1.9977933168411255, 'ceo': 0.000683128833770752, 'mason': -0.997454822063446, 'foursquare': 0.9978405237197876, 'io': 0.9978405237197876, 'ebitda': -1.9972655773162842, 'customer': 0.002583146095275879, 'ad': 0.9982419013977051, 'downgrade': -0.9989418387413025, 'amazon': -0.9175528883934021, 'nyse': 0.9980864524841309, 'agent': -0.9983349442481995, 'marketing': -0.9949040412902832, 'profit': -0.9826676249504089, 'investor': -0.9966087341308594, 'crash': -0.9989957213401794, 'rally': 0.9975461363792419, 'tech': 0.9975461363792419, 'acquisition': 0.5293223857879639}
# sentiment dict: 30 keyword count: 30
# industry score: -0.059080867717663445
# ----------------------------------------------------------
# industry: entertainment
# [['LGF.A', 'More on Lions Gate Entertainment (LGF): FQ4 swings to a loss on higher marketing and acquisition costs from its January acquisition of Summit Entertainment. Revenue surged 71% Y/Y on "The Hunger Games" box office receipts, as well as home entertainment sales of "The Twilight Saga: Breaking Dawn: Part 1.." Shares -5% AH.', '2012-05-30'], ['LGF.A', 'Lions Gate Entertainment (LGF): FQ4 EPS of -$0.17 may not be comparable to consensus of $0.27. Revenue of $645.2M (+71% Y/Y) beats by $27M. Shares -3% AH. (PR)', '2012-05-30'], ['NFLX', 'Netflix (NASDAQ:NFLX) -6.3% after BofA cuts its 2012 earnings forecast for the company, citing fears about U.S. streaming growth and the costs related to its international expansion.', '2012-05-31'], ['LGF.A', 'Execs with Lions Gate (LGF +1.3%) say on a CC that 90% of the profit for The Hunger Games still lies ahead for the company. Shares of LGF have started to move up during the course of the call after sitting in negative territory premarket. (webcast)', '2012-05-31'], ['SIRI', "Sirius XM Radio (SIRI -1.6%) falls back on above-average volume with the anticipated sale of shares by Mel Karmazin this week or next sitting as an overhang. Though the block sales are part of 10b5-1 plan not related to any non-public information, SIRI has still taken a hit each time one of Karmazin's transactions is officially announced.", '2012-06-18'], ['SIRI', 'Shares of Sirius XM Radio (SIRI +4.1%) shoot higher on the strength of some outsized block trades. SA author Crunching Numbers says shares could trek back to $2.15 based on implications of where Liberty Media sees fair value.', '2012-06-19'], ['AMCX', 'Shares of AMC Networks (AMCX +0.1%) trade flat after Dish Networks (DISH +2.9%) calls its bluff and says it will drop three of its channels from its lineup of programming tonight. On the other side of the coin, Dish is airing its own commercial-free programming on the trio of networks and will take a bit of a revenue hit as it gambles that it will gain it all back and more if it secures a lower fee structure from AMC in the future.', '2012-06-29'], ['NFLX', "Netflix (NFLX +6.3%) surges thanks to a bullish note from Citi's Mark Mahaney, who points out the company now trades at a valuation of just 12x the earnings of its domestic ops (ed: the international business is losing money, and including it would produce a higher multiple). Mahaney also claims recent customer surveys reflect favorably on Netflix. 26% of Netflix's float was shorted as of June 15.", '2012-07-03'], ['NFLX', 'The sudden rise in Neflix (NFLX +13.5%), up over 19% for the week, is starting to look overdone to a horde of skeptics. The question of the day on NFLX: Does an anecdotal Facebook post about streaming hours translate into paid subscriber growth?', '2012-07-05'], ['NFLX', "Netflix (NFLX +8.5%) extends Tuesday's rally as bulls go long and bears cover following positive sell-side commentary, and a Facebook post from Reed Hastings claiming Netflix's monthly viewing topped 1B hours in June. BTIG's Richard Greenfield estimates this translates into 80 minutes of viewing per subscriber, a level that puts Netflix on par with leading cable networks.", '2012-07-05'], ['SIRI', "Shares of Sirius XM Radio (SIRI -2.2%) give back a bit of the gains they churned up after June automobile sales came in strong. While steady demand is crucial for the company, it's also only one part of the equation as conversion rates still need to be maintained to keep sales projections on track.", '2012-07-06'], ['NFLX', "The rally in shares of Netflix (NFLX +2.9%) keeps motoring right along even against a weak tape. The buying frenzy was started by a Facebook post by CEO Reed Hastings on the company's tally of streaming hours by customers, but questions on whether or not Hastings skirted SEC Regulation FD with his bravado are starting to crop up.", '2012-07-06'], ['SIRI', "Sirius XM Radio (NASDAQ:SIRI) opens 3.2% higher on heavy volume after reporting new subscri ...
# ind head: 29
# {'nasdaq': -1.9986528754234314, 'profit': 0.995262622833252, 'hunger': 0.995262622833252, 'sirius': 2.997485339641571, 'channel': -0.9978086352348328, 'dish': -0.9978086352348328, 'valuation': 0.997514009475708, 'subscriber': 0.009864866733551025, 'rally': 9.312580823898316e-05, 'disney': 1.9961705803871155, 'shareholder': 0.9980586171150208, 'avenger': 0.9980586171150208, 'dis': 1.9961705803871155, 'cinema': 0.998191773891449, 'footage': 0.998191773891449, 'stream': -0.9989207983016968, 'dvd': -0.9988365769386292, 'underperform': -0.9988365769386292, 'pandora': 0.9979690909385681, 'volatility': 8.881859183311462e-05, 'gate': 8.881859183311462e-05, 'lion': -0.9844182653009892, 'investor': 0.00028856069445610047, 'manchester': -0.996130108833313, 'amazon': -0.9984627962112427, 'prime': -0.9984627962112427, 'apple': 0.9981119632720947}
# sentiment dict: 27 keyword count: 27
# industry score: 0.11925080279934974
# ----------------------------------------------------------
# industry: travel-services
# [['CCL', 'Carnival (NYSE:CCL): FQ2 EPS of $0.20 beats by $0.13. Revenue of $3.5B (-2.2%% Y/Y) misses by $50M. Shares +1.8% premarket. (PR)', '2012-06-22'], ['TRIP', "More on TripAdvisor (NASDAQ:TRIP): Q2 results hit consensus on EPS but misses slightly on revenue. Analysts had been looking for an improvement to revenue due to reinvestment, hurting margins temporarily but holding per share earnings solid. Q2's EPS matches the Street, but it's based on a slight improvement in adjusted margins to 49% versus Q1's 46% - suggesting the company held off on planned investments to keep its bottom-line healthy. Click-based ad revenue also slowed, increasing 13% for the current quarter compared to 20% in Q1. Shares -19.7% AH.", '2012-07-24'], ['TRIP', 'Tripadvisor (NASDAQ:TRIP): Q2 EPS of $0.41 in-line. Revenue of $197.1M (+16.5% Y/Y) misses by $5M. Shares -20% AH. (PR)', '2012-07-24'], ['EXPE', "More on Expedia's Q2: Strong results fueled by 20% Y/Y increase in transactions of 23.1M (Q1 had 18% growth). Hotel room nights +22%, revenue per room night -5%. Air tickets sold +3%, revenue per air ticket -11%. International revenue 38% of total, even with prior year. Cost of revenue +17%, outpacing revenue growth. 3M shares repurchased at average price of $33.24. EXPE +12.1% AH. PCLN +1.9%. TRIP +2.5%. (PR)", '2012-07-26'], ['EXPE', 'Expedia (NASDAQ:EXPE): Q2 EPS of $0.76 beats by $0.05. Revenue of $1.04B (+13.8% Y/Y) beats by $150M. Shares +11.5% AH. (PR)', '2012-07-26'], ['EXPE', "Expedia's (EXPE +20.1%) stellar Q2 report, which featured a 22% Y/Y jump in hotel bookings, ended up fueling a strong rally in online travel stocks. PCLN +8.9%. OWW +7.3%. TZOO +4.9%. KYAK +2.8%. During its earnings call, Expedia guided for low double-digit 2012 revenue growth (consensus is for 10.6%) and high single-digit EBITDA growth. Still, Pac Crest is on edge over comments about weakening Southern European demand, and Deutsche thinks Priceline is a better buy. (Q1 rally)", '2012-07-27'], ['EXPE', "Online travel names head south in response to Priceline's soft Q3 guidance. EXPE -3.2% AH. TRIP -6.3%. Of particular concern is Priceline's guidance for a 12%-20% Y/Y increase in international gross bookings (heavily tied to Europe), which is well below Q2's 33%, not to mention Q1's 54%. Also, guidance for Q3 revenue growth of 9%-15% isn't close to a 24% consensus. OWW and TZOO could also be under pressure tomorrow. PCLN -15.4% AH. The CC has started (webcast).", '2012-08-07'], ['BKNG', 'More on Priceline (PCLN): Expects total gross bookings to increase 10%-18% Y/Y in Q3, with domestic bookings 5% higher. Says its below-Street guidance reflects current operating trends as well as an assumption that economic conditions in Europe will deteriorate again. Shares -12.2% AH.  (PR)', '2012-08-07'], ['BKNG', 'Priceline (PCLN): Q2 EPS of $7.85 beats by $0.48. Revenue of $1.36B (+26.8% Y/Y) misses by $1M. Sees Q3 2012 EPS of $11.10-$11.12 vs. $12.82 consensus. Shares -8.5% AH. (PR)', '2012-08-07'], ['TRIP', "Tripadvisor (TRIP -6.0%) and Orbitz Worldwide (OWW -4.2%) slump after the WSJ reports Google will buy the Frommer's brand from John Wiley & Sons (JW.A -0.6%) for an undisclosed amount. A combination of Frommer's with previously-purchased Zagat's poses a threat to the online travel sites.", '2012-08-13']]
# ind head: 10
# {'nasdaq': -0.9968418478965759, 'pr': 0.9979469180107117, 'ebitda': 0.9970353841781616, 'stellar': 0.9970353841781616, 'booking': -0.0023757219314575195}
# sentiment dict: 5 keyword count: 5
# industry score: 0.24910001456737518
# company: GOOGL
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: META
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BIDU
# [["Chinese Internet stocks, many of whom fell yesterday on worries about the Middle Kingdom's growth outlook, are falling harder today. BIDU -4.9%. SINA -7.9%. YOKU -9.1%. TUDO -9%. SOHU -5.4%. RENN -5.8%.", '2012-07-17'], ["More on Baidu's Q2: 352K online ad customers, +9.7% Q/Q and +18.1% Y/Y. Revenue/customer was $2,440, +16.5% Q/Q and +34.8% Y/Y. Traffic acquisition costs were 8.3% of revenue, up from 7.8% in Q1 and 7.9% in year-ago period. SG&A expenses +55.6% Y/Y, R&D expenses +82.7%. BIDU +5.5% AH. Up in sympathy: SINA +2.8%. SOHU +2.5%. YOKU +1.7%. (PR)", '2012-07-23'], ['Baidu (NASDAQ:BIDU): Q2 EPS of $1.26 beats by $0.14. Revenue of $858.8M (+59.8% Y/Y) beats by $8M. Expects Q3 revenue of $983M-$1.01B vs. $988M consensus. Shares +6.6% AH. (PR)', '2012-07-23'], ["Beaten down on macro and mobile worries, Baidu (BIDU +10%) is rallying strongly after its Q2 report and Q3 guidance made it clear that the Chinese search giant's growth remains quite healthy for now. Barclays (Overweight) sees the report, which featured a major increase in ad revenue/customer, as evidence of the untapped opportunity presented by Chinese SMEs. Multiple analysts note the strength of Baidu's display ad sales to third-party sites. SINA +1.7%. (transcript)", '2012-07-24']]
# company_allnews_sentiment: {"Chinese Internet stocks, many of whom fell yesterday on worries about the Middle Kingdom's growth outlook, are falling harder today. BIDU -4.9%. SINA -7.9%. YOKU -9.1%. TUDO -9%. SOHU -5.4%. RENN -5.8%.": -0.9989815354347229, "More on Baidu's Q2: 352K online ad customers, +9.7% Q/Q and +18.1% Y/Y. Revenue/customer was $2,440, +16.5% Q/Q and +34.8% Y/Y. Traffic acquisition costs were 8.3% of revenue, up from 7.8% in Q1 and 7.9% in year-ago period. SG&A expenses +55.6% Y/Y, R&D expenses +82.7%. BIDU +5.5% AH. Up in sympathy: SINA +2.8%. SOHU +2.5%. YOKU +1.7%. (PR)": 0.9974871873855591, 'Baidu (NASDAQ:BIDU): Q2 EPS of $1.26 beats by $0.14. Revenue of $858.8M (+59.8% Y/Y) beats by $8M. Expects Q3 revenue of $983M-$1.01B vs. $988M consensus. Shares +6.6% AH. (PR)': 0.9971129894256592, "Beaten down on macro and mobile worries, Baidu (BIDU +10%) is rallying strongly after its Q2 report and Q3 guidance made it clear that the Chinese search giant's growth remains quite healthy for now. Barclays (Overweight) sees the report, which featured a major increase in ad revenue/customer, as evidence of the untapped opportunity presented by Chinese SMEs. Multiple analysts note the strength of Baidu's display ad sales to third-party sites. SINA +1.7%. (transcript)": 0.9982419013977051}
# company_subset_sentiment: {"More on Baidu's Q2: 352K online ad customers, +9.7% Q/Q and +18.1% Y/Y. Revenue/customer was $2,440, +16.5% Q/Q and +34.8% Y/Y. Traffic acquisition costs were 8.3% of revenue, up from 7.8% in Q1 and 7.9% in year-ago period. SG&A expenses +55.6% Y/Y, R&D expenses +82.7%. BIDU +5.5% AH. Up in sympathy: SINA +2.8%. SOHU +2.5%. YOKU +1.7%. (PR)": 0.9974871873855591, 'Baidu (NASDAQ:BIDU): Q2 EPS of $1.26 beats by $0.14. Revenue of $858.8M (+59.8% Y/Y) beats by $8M. Expects Q3 revenue of $983M-$1.01B vs. $988M consensus. Shares +6.6% AH. (PR)': 0.9971129894256592, "Beaten down on macro and mobile worries, Baidu (BIDU +10%) is rallying strongly after its Q2 report and Q3 guidance made it clear that the Chinese search giant's growth remains quite healthy for now. Barclays (Overweight) sees the report, which featured a major increase in ad revenue/customer, as evidence of the untapped opportunity presented by Chinese SMEs. Multiple analysts note the strength of Baidu's display ad sales to third-party sites. SINA +1.7%. (transcript)": 0.9982419013977051}
# company score (all news concerned): 0.4984651356935501
# company score (as influenced by industry): 0.9976140260696411
# company: SPOT
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: DASH
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: SNAP
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: PINS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TME
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MTCH
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TWLO
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: Z
# [["Zillow (Z +5.8%) jumps on an upgrade to Outperform from Pac Crest. A full 50.1% of the company's float was shorted as of May 31, but Steven Cohen's SAC Capital has been a buyer.", '2012-06-14'], ["More on Zillow's Q2: The company expects Q3 revenue of $30M-$31M, in-line with a $30.3M consensus. However, adjusted EBITDA is expected to drop to $4.75M-$5.25M from Q2's $5.3M, which suggests EPS could miss a $0.06 consensus. Monthly unique users +5% Q/Q and +61% Y/Y to 33.5M, and Premier Agent subs rose by 4.1K to 22.7K. Also, more homes are now viewed on mobile devices than on PCs (previous). Z -12.6% AH, shares had rallied going into the report.", '2012-08-07'], ['Zillow (NASDAQ:Z): Q2 EPS of $0.04 in-line. Revenue of $27.8M (+75.9% Y/Y) beats by $0.6M. Shares -3% AH. (PR)', '2012-08-07'], ['Zillow (NASDAQ:Z) -2.6% AH after announcing a 3.5M share stock offering - 3.175M newly-issued shares, and 325K sold by insiders. The offering stands to increase the real estate site\'s share count by 11%, and would raise $134.6M at current levels. Zillow only says it will use the proceeds for "general corporate purposes," which may include acquisitions. (PR)', '2012-09-05']]
# company_allnews_sentiment: {"Zillow (Z +5.8%) jumps on an upgrade to Outperform from Pac Crest. A full 50.1% of the company's float was shorted as of May 31, but Steven Cohen's SAC Capital has been a buyer.": 0.9978571534156799, "More on Zillow's Q2: The company expects Q3 revenue of $30M-$31M, in-line with a $30.3M consensus. However, adjusted EBITDA is expected to drop to $4.75M-$5.25M from Q2's $5.3M, which suggests EPS could miss a $0.06 consensus. Monthly unique users +5% Q/Q and +61% Y/Y to 33.5M, and Premier Agent subs rose by 4.1K to 22.7K. Also, more homes are now viewed on mobile devices than on PCs (previous). Z -12.6% AH, shares had rallied going into the report.": -0.9983349442481995, 'Zillow (NASDAQ:Z): Q2 EPS of $0.04 in-line. Revenue of $27.8M (+75.9% Y/Y) beats by $0.6M. Shares -3% AH. (PR)': 0.9977074861526489, 'Zillow (NASDAQ:Z) -2.6% AH after announcing a 3.5M share stock offering - 3.175M newly-issued shares, and 325K sold by insiders. The offering stands to increase the real estate site\'s share count by 11%, and would raise $134.6M at current levels. Zillow only says it will use the proceeds for "general corporate purposes," which may include acquisitions. (PR)': 0.5293223857879639}
# company_subset_sentiment: {"Zillow (Z +5.8%) jumps on an upgrade to Outperform from Pac Crest. A full 50.1% of the company's float was shorted as of May 31, but Steven Cohen's SAC Capital has been a buyer.": 0.9978571534156799, "More on Zillow's Q2: The company expects Q3 revenue of $30M-$31M, in-line with a $30.3M consensus. However, adjusted EBITDA is expected to drop to $4.75M-$5.25M from Q2's $5.3M, which suggests EPS could miss a $0.06 consensus. Monthly unique users +5% Q/Q and +61% Y/Y to 33.5M, and Premier Agent subs rose by 4.1K to 22.7K. Also, more homes are now viewed on mobile devices than on PCs (previous). Z -12.6% AH, shares had rallied going into the report.": -0.9983349442481995, 'Zillow (NASDAQ:Z): Q2 EPS of $0.04 in-line. Revenue of $27.8M (+75.9% Y/Y) beats by $0.6M. Shares -3% AH. (PR)': 0.9977074861526489, 'Zillow (NASDAQ:Z) -2.6% AH after announcing a 3.5M share stock offering - 3.175M newly-issued shares, and 325K sold by insiders. The offering stands to increase the real estate site\'s share count by 11%, and would raise $134.6M at current levels. Zillow only says it will use the proceeds for "general corporate purposes," which may include acquisitions. (PR)': 0.5293223857879639}
# company score (all news concerned): 0.3816380202770233
# company score (as influenced by industry): 0.3816380202770233
# company: IAC
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: ATHM
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: WB
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: YELP
# [["Yelp (YELP -3.7%) is joining in on a general selloff in high-beta Internet and social networking names; shares are now down 25% since the day of Facebook's IPO, and are closing in on the company's IPO price of $15. Google's (NASDAQ:GOOG) recent overhaul of its local commerce content, which includes the arrival of free Zagat reviews, could also be weighing on shares.", '2012-05-31'], ["Yelp (YELP +7.6%) soars to levels last seen in early April, as speculation grows that Apple plans to integrate Yelp's check-in feature for points of interest within its new mapping software (previous), which will accompany iOS 6. There's no word on whether Foursquare or Facebook's (NASDAQ:FB) check-in features will also be integrated.", '2012-07-05'], ['Yelp (NYSE:YELP): Q2 EPS of -$0.03 beats by $0.03. Revenue of $32.7M (+67% Y/Y) beats by $2.2M. Expects Q3 revenue of $34.5M-$35.5M, above $34.3M consensus. Expects 2012 revenue of $135M-$136M, above $130.7M consensus. Shares +7.5% AH. (PR)', '2012-08-01'], ['Amidst the carnage of recent consumer Web IPOs, Yelp (YELP +22.5%) has become a standout. Shares are taking off after Yelp beat Q2 estimates, raised guidance, and reported a 9% Q/Q increase in monthly unique users to 78M. During its earnings call,', '2012-08-02'], ["Yelp (YELP +6.1%) has turned into one of the day's top tech performers, in spite of having no major news to rally on. There could be more short-covering going on following last week's huge post-lockup-expiration rally.", '2012-09-04'], ["Yelp (YELP +6.5%) has registered big gains for the second day in a row (previous); shares are now up 41% since the reviews site's lockup expiration ended last Wednesday. Today's gains follow an upbeat presentation from CEO Jeremy Stoppelman at a Citi conference (webcast). Stoppelman reiterated the strong performance of ads on Yelp's mobile site, and estimated 25% of unique users come from mobile devices (ed: that's actually lower than some other Web services).", '2012-09-05']]
# company_allnews_sentiment: {"Yelp (YELP -3.7%) is joining in on a general selloff in high-beta Internet and social networking names; shares are now down 25% since the day of Facebook's IPO, and are closing in on the company's IPO price of $15. Google's (NASDAQ:GOOG) recent overhaul of its local commerce content, which includes the arrival of free Zagat reviews, could also be weighing on shares.": -0.9988855719566345, "Yelp (YELP +7.6%) soars to levels last seen in early April, as speculation grows that Apple plans to integrate Yelp's check-in feature for points of interest within its new mapping software (previous), which will accompany iOS 6. There's no word on whether Foursquare or Facebook's (NASDAQ:FB) check-in features will also be integrated.": 0.9978405237197876, 'Yelp (NYSE:YELP): Q2 EPS of -$0.03 beats by $0.03. Revenue of $32.7M (+67% Y/Y) beats by $2.2M. Expects Q3 revenue of $34.5M-$35.5M, above $34.3M consensus. Expects 2012 revenue of $135M-$136M, above $130.7M consensus. Shares +7.5% AH. (PR)': 0.9980864524841309, 'Amidst the carnage of recent consumer Web IPOs, Yelp (YELP +22.5%) has become a standout. Shares are taking off after Yelp beat Q2 estimates, raised guidance, and reported a 9% Q/Q increase in monthly unique users to 78M. During its earnings call,': 0.9980915188789368, "Yelp (YELP +6.1%) has turned into one of the day's top tech performers, in spite of having no major news to rally on. There could be more short-covering going on following last week's huge post-lockup-expiration rally.": 0.9975461363792419, "Yelp (YELP +6.5%) has registered big gains for the second day in a row (previous); shares are now up 41% since the reviews site's lockup expiration ended last Wednesday. Today's gains follow an upbeat presentation from CEO Jeremy Stoppelman at a Citi conference (webcast). Stoppelman reiterated the strong performance of ads on Yelp's mobile site, and estimated 25% of unique users come from mobile devices (ed: that's actually lower than some other Web services).": 0.9981379508972168}
# ...
# company: PARA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: ROKU
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: WWE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: EDR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: NXST
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: IQ
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MSGS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MANU
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: AMC
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BATRK
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CNK
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BOWL
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: LGF.A
# [["Shares of Lions Gate (LGF) move 2.9% higher premarket after the company debuted its latest Twilight film, Breaking Dawn Part 2. The box office haul was better than expected globally, although U.S. numbers didn't quite match the second film in the trilogy. The bigger issue: Hollywood insiders say the Twilight films changed the industry even more than Harry Potter with adaptions of series aimed at teenagers now the sweet spot for studios. Watch for Stephanie Meyer's The Host to be the next rainmaker.", '2012-11-19']]
# company_allnews_sentiment: {"Shares of Lions Gate (LGF) move 2.9% higher premarket after the company debuted its latest Twilight film, Breaking Dawn Part 2. The box office haul was better than expected globally, although U.S. numbers didn't quite match the second film in the trilogy. The bigger issue: Hollywood insiders say the Twilight films changed the industry even more than Harry Potter with adaptions of series aimed at teenagers now the sweet spot for studios. Watch for Stephanie Meyer's The Host to be the next rainmaker.": 0.9976935982704163}
# company_subset_sentiment: {"Shares of Lions Gate (LGF) move 2.9% higher premarket after the company debuted its latest Twilight film, Breaking Dawn Part 2. The box office haul was better than expected globally, although U.S. numbers didn't quite match the second film in the trilogy. The bigger issue: Hollywood insiders say the Twilight films changed the industry even more than Harry Potter with adaptions of series aimed at teenagers now the sweet spot for studios. Watch for Stephanie Meyer's The Host to be the next rainmaker.": 0.9976935982704163}
# company score (all news concerned): 0.9976935982704163
# company score (as influenced by industry): 0.9976935982704163
# company: PLAY
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MSGE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: SPHR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: IMAX
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: HUYA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: SBGI
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: AMCX
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MCS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: RSVR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: LVO
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: GNUS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: RDI
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: HOFV
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: GAIA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MMV
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: AGAE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CSSE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: ANGH
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: DLPN
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BREA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: KUKE
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CNVS
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CPOP
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: ADD
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: BKNG
# [['Priceline.com (PCLN) bounces 4.2% higher in premarket action after Expedia delivers a strong Q3. The bounce in the online travel could also be a bit of a relief rally after Google cast a dark shadow on the sector with comments on "weak travel" on its Q3 earnings CC (transcript).', '2012-10-26'], ['Priceline (PCLN -4.7%) and Expedia (EXPE -3.5%) are off after Deutsche downgrades Priceline to Hold on a belief a margin-compressing "Cold War" will break out in European online travel. The culprits: Expedia\'s growing efforts to acquire customers following an improvement in conversion rates; a declining amount of travel-related Google (NASDAQ:GOOG) PC ad clicks thanks to the mobile shift; and the possibility Google will make a stronger travel search push once its regulatory issues are handled.', '2012-12-10']]
# company_allnews_sentiment: {'Priceline.com (PCLN) bounces 4.2% higher in premarket action after Expedia delivers a strong Q3. The bounce in the online travel could also be a bit of a relief rally after Google cast a dark shadow on the sector with comments on "weak travel" on its Q3 earnings CC (transcript).': 0.9973068237304688, 'Priceline (PCLN -4.7%) and Expedia (EXPE -3.5%) are off after Deutsche downgrades Priceline to Hold on a belief a margin-compressing "Cold War" will break out in European online travel. The culprits: Expedia\'s growing efforts to acquire customers following an improvement in conversion rates; a declining amount of travel-related Google (NASDAQ:GOOG) PC ad clicks thanks to the mobile shift; and the possibility Google will make a stronger travel search push once its regulatory issues are handled.': -0.9984652996063232}
# company_subset_sentiment: {'Priceline.com (PCLN) bounces 4.2% higher in premarket action after Expedia delivers a strong Q3. The bounce in the online travel could also be a bit of a relief rally after Google cast a dark shadow on the sector with comments on "weak travel" on its Q3 earnings CC (transcript).': 0.9973068237304688}
# company score (all news concerned): -0.0005792379379272461
# company score (as influenced by industry): 0.9973068237304688
# company: ABNB
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: RCL
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TCOM
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: CCL
# [['Carnival (NYSE:CCL): FQ4 EPS of $0.13 beats by $0.01. Revenue of $3.6B beats by $0.06B. Shares  -2.6% premarket. (PR)', '2012-12-20']]
# company_allnews_sentiment: {'Carnival (NYSE:CCL): FQ4 EPS of $0.13 beats by $0.01. Revenue of $3.6B beats by $0.06B. Shares  -2.6% premarket. (PR)': 0.9973210692405701}
# company_subset_sentiment: {}
# company score (all news concerned): 0.9973210692405701
# company score (as influenced by industry): 0
# company: EXPE
# [['Premarket gainers: EXPE +16%. PPC +11%. ACI +10%. GALE +6%. JRCC +6%. LOGI +6%.  Losers: CBRX -28%. CTCT -22%. DECK -19%. VRSN -17%. IMOS -15%. SPF -6%. ERIC -5%. CSTR -5%.', '2012-10-26'], ['Shares of Expedia (NASDAQ:EXPE) trade 16.7% higher premarket after the company beats estimates with its Q3 report. Strong bookings and the growth of its global business were the highlights from the quarter. Analysts are jumping on board with three upgrades already on the books, led by Benchmark lifting the stock to Buy.', '2012-10-26'], ["Online travel stocks are underperforming on a day when Expedia (EXPE -2.2%) announced it's buying 61% of popular German hotel bookings site Trivago. PCLN -2.4%. TRIP -2.7%. OWW -4.6%. TZOO -3.3%. Priceline received 83% of its Q3 gross bookings from international markets, and the bulk of that came from Europe.", '2012-12-21']]
# company_allnews_sentiment: {'Premarket gainers: EXPE +16%. PPC +11%. ACI +10%. GALE +6%. JRCC +6%. LOGI +6%.  Losers: CBRX -28%. CTCT -22%. DECK -19%. VRSN -17%. IMOS -15%. SPF -6%. ERIC -5%. CSTR -5%.': 0.9970220923423767, 'Shares of Expedia (NASDAQ:EXPE) trade 16.7% higher premarket after the company beats estimates with its Q3 report. Strong bookings and the growth of its global business were the highlights from the quarter. Analysts are jumping on board with three upgrades already on the books, led by Benchmark lifting the stock to Buy.': 0.9982538819313049, "Online travel stocks are underperforming on a day when Expedia (EXPE -2.2%) announced it's buying 61% of popular German hotel bookings site Trivago. PCLN -2.4%. TRIP -2.7%. OWW -4.6%. TZOO -3.3%. Priceline received 83% of its Q3 gross bookings from international markets, and the bulk of that came from Europe.": -0.9984983205795288}
# company_subset_sentiment: {'Premarket gainers: EXPE +16%. PPC +11%. ACI +10%. GALE +6%. JRCC +6%. LOGI +6%.  Losers: CBRX -28%. CTCT -22%. DECK -19%. VRSN -17%. IMOS -15%. SPF -6%. ERIC -5%. CSTR -5%.': 0.9970220923423767, 'Shares of Expedia (NASDAQ:EXPE) trade 16.7% higher premarket after the company beats estimates with its Q3 report. Strong bookings and the growth of its global business were the highlights from the quarter. Analysts are jumping on board with three upgrades already on the books, led by Benchmark lifting the stock to Buy.': 0.9982538819313049, "Online travel stocks are underperforming on a day when Expedia (EXPE -2.2%) announced it's buying 61% of popular German hotel bookings site Trivago. PCLN -2.4%. TRIP -2.7%. OWW -4.6%. TZOO -3.3%. Priceline received 83% of its Q3 gross bookings from international markets, and the bulk of that came from Europe.": -0.9984983205795288}
# company score (all news concerned): 0.33225921789805096
# company score (as influenced by industry): 0.33225921789805096
# company: NCLH
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TNL
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MMYT
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TRIP
# [["TripAdvisor (TRIP +7.7%) has rallied to $41.35 on news Liberty Interactive (LINTA +0.1%) acquired voting control by purchasing 4.8M shares at $62.50. LINTA now controls 57% of TRIP's voting rights, though only 22% of its equity. Orbitz (OWW +3%) and Travelzoo (TZOO +3.3%) are joining Expedia in rising in sympathy.", '2012-12-11']]
# company_allnews_sentiment: {"TripAdvisor (TRIP +7.7%) has rallied to $41.35 on news Liberty Interactive (LINTA +0.1%) acquired voting control by purchasing 4.8M shares at $62.50. LINTA now controls 57% of TRIP's voting rights, though only 22% of its equity. Orbitz (OWW +3%) and Travelzoo (TZOO +3.3%) are joining Expedia in rising in sympathy.": 0.9980035424232483}
# company_subset_sentiment: {"TripAdvisor (TRIP +7.7%) has rallied to $41.35 on news Liberty Interactive (LINTA +0.1%) acquired voting control by purchasing 4.8M shares at $62.50. LINTA now controls 57% of TRIP's voting rights, though only 22% of its equity. Orbitz (OWW +3%) and Travelzoo (TZOO +3.3%) are joining Expedia in rising in sympathy.": 0.9980035424232483}
# company score (all news concerned): 0.9980035424232483
# company score (as influenced by industry): 0.9980035424232483
# company: SABR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: MOND
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: LIND
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: DESP
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: TOUR
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0
# company: YTRA
# []
# company_allnews_sentiment: {}
# company_subset_sentiment: {}
# company score (all news concerned): 0
# company score (as influenced by industry): 0

# %%
json_industry
# Out:
# {'internet-content-and-information': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': 0.050223736535935176},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.17748178243637086},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 0.22816975870910955},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.5524081413338824},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.39840001430151595},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.24147548278172812},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': -0.059080867717663445},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': -0.06592800253528659},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': -0.11751161404510042},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': -0.24016235828399657},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': -0.19436233615676565},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': -0.00949459141396188}],
#  'entertainment': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': 0.45755390999680856},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': 0.2337603816619286},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 0.5469936342759409},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.36247623987188415},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.19090899487428548},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.2949472354332606},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.11925080279934974},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': 0.3326043196990755},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.5611709762023556},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': 0.42010196381727855},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': 0.45166862447002004},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.5402705814766388}],
#  'travel-services': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.05012718632355332},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.20002415372121335},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': -0.11115495513445801},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.18147238215722822},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.35660059083018986},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.9977356990178426},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.24910001456737518},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': 0.24910001456737518},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.9975193321704865},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.760745504323174},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': 0.6879305243492126},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.598417603969574}]}

# %%
json_company
# Out:
# {'GOOGL': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'META': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'BIDU': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.6565998842318853},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.7421889404455821},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': -0.19527823925018312},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.2910334897706906},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': -0.00017653966347377},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': -0.49949076771736145},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.7480395808815956},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': -6.335973739626799e-06},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': -0.8553875528630757},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': -0.9987349460522335},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': -0.9988089725375175},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': -0.9987743298212688}],
#  'SPOT': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'DASH': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'SNAP': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'PINS': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TME': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'MTCH': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TWLO': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'Z': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': 0.9980162878831227},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': 0.41575599958499276},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 0.5488760605454445},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.9981576800346375},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.9980074167251587},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.9978571534156799},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.3816380202770233},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': 0.07234591245651245},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.004174956679344179},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': 0.013411084810892739},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': -0.245957650244236},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'IAC': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': 0.49852320551872253},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': -0.29194602370262146},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': -0.29194602370262146},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': -0.29194602370262146},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': 0.9777718782424927},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.9777718782424927},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': -0.9985648989677429},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': -0.16671431064605713},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': -0.0004680752754211426}],
#  'ATHM': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'WB': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'YELP': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.32428834835688275},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.4425443112850189},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 0.4740105217153376},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.9977561405726841},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.9976426437497139},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.665052721897761},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.6651361684004465},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': 0.3987865447998047},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': -0.000533918539683024},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': -0.49958720058202744},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': -0.4040384462901524},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.04188469052314758}],
#  'CARG': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'YY': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.997772753238678},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.997772753238678}],
#  'GETY': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'MOMO': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'SSTK': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.9981614947319031},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': 0.9981614947319031},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'ANGI': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.9984079003334045},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': 0.9981929659843445},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 0.9981929659843445},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.002600163221359253},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.002600163221359253},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.002600163221359253},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': -0.9966087341308594},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': -0.7990452975034714},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': -0.7990452975034714},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': -0.16749748339255652},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': 0.9977521697680155},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.9980213642120361}],
#  'OPRA': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'PERI': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'SEAT': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'GENI': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'KIND': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'FVRR': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TBLA': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TTGT': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'MATH': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'THRY': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'ZH': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'MAX': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'SMWB': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TRVG': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'NN': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'DOYU': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'JFIN': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'OB': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'EVER': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TRUE': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'GRPN': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.07310513371513003},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.2920345208711094},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': -0.7040959894657135},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.2464171454310417},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.11799744000298935},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.14370224465216908},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': -0.7971987370991599},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': -0.7739930053551991},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': -0.43306288072331384},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': -0.31010268756321496},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': -0.4918823802251082},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': -0.20736643010377884}],
#  'LTRPA': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'STBX': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'BODY': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': 0.4986993670463562},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.33341532945632935},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': -0.27729282528162},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.39053821563720703},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': -0.5539484024047852},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': -0.6661493380864462},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': -0.6661493380864462},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': -0.00026732683181762695},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'SCOR': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': -0.9987516403198242},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': -0.9987516403198242},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': -0.9987516403198242},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'AREN': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'BZFD': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'EGLX': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'CMCM': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'LIZI': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'UPXI': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'IZEA': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'FAZE': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'KRKR': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'ASST': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'ZDGE': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'FENG': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
# ...
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'CPOP': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'ADD': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'BKNG': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': 0.9980490207672119},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': 0.9980537295341492},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 0.9980729619661968},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.41684692104657495},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': -0.3304443359375},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.4980345815420151},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': 0.2484947368502617},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.33237055937449134},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': 0.9885840564966202},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': 0.7374871596693993},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.49836379289627075}],
#  'ABNB': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'RCL': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': 7.048909217119217e-05},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': 7.048909217119217e-05},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 4.7203034162521365e-05},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': -0.0006856322288513184},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.33218175172805786},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.9979165196418762},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TCOM': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'CCL': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.0006476267528533919},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.11143052746918464},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': -0.3092758612148109},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': -0.4161971114908656},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.49774476885795593},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.49774476885795593},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.4989836513996124},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': 0.4989836513996124},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.49866053462028503}],
#  'EXPE': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.6645117387165625},
#   {'start': '2012-02-01',
#    'end': '2012-02-31',
#    'sentiment': -0.4992825962588191},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': -0.9983083009719849},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.09471662129674639},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.4987320850292842},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.7481342256069183},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': 0.4152148415644964},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': 0.4152148415644964},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.7979867796103159},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.465444752573967},
#   {'start': '2012-11-01',
#    'end': '2012-11-31',
#    'sentiment': 0.49872706830501556},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.33225921789805096}],
#  'NCLH': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TNL': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'MMYT': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 6.961424350738525e-05},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 6.961424350738525e-05},
#   {'start': '2012-05-01',
#    'end': '2012-05-31',
#    'sentiment': 0.49899247089624404},
#   {'start': '2012-06-01',
#    'end': '2012-06-31',
#    'sentiment': 0.9979153275489807},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TRIP': [{'start': '2012-01-01',
#    'end': '2012-01-31',
#    'sentiment': -0.1665367359916369},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': -0.99845951795578},
#   {'start': '2012-03-01',
#    'end': '2012-03-31',
#    'sentiment': 0.9979795813560486},
#   {'start': '2012-04-01',
#    'end': '2012-04-31',
#    'sentiment': 0.9979795813560486},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01',
#    'end': '2012-07-31',
#    'sentiment': -0.997612605492274},
#   {'start': '2012-08-01',
#    'end': '2012-08-31',
#    'sentiment': -0.997612605492274},
#   {'start': '2012-09-01',
#    'end': '2012-09-31',
#    'sentiment': 0.9974974989891052},
#   {'start': '2012-10-01',
#    'end': '2012-10-31',
#    'sentiment': 0.9976810216903687},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.997961183389028},
#   {'start': '2012-12-01',
#    'end': '2012-12-31',
#    'sentiment': 0.9980035424232483}],
#  'SABR': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'MOND': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'LIND': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'DESP': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'TOUR': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}],
#  'YTRA': [{'start': '2012-01-01', 'end': '2012-01-31', 'sentiment': 0.0},
#   {'start': '2012-02-01', 'end': '2012-02-31', 'sentiment': 0.0},
#   {'start': '2012-03-01', 'end': '2012-03-31', 'sentiment': 0.0},
#   {'start': '2012-04-01', 'end': '2012-04-31', 'sentiment': 0.0},
#   {'start': '2012-05-01', 'end': '2012-05-31', 'sentiment': 0.0},
#   {'start': '2012-06-01', 'end': '2012-06-31', 'sentiment': 0.0},
#   {'start': '2012-07-01', 'end': '2012-07-31', 'sentiment': 0.0},
#   {'start': '2012-08-01', 'end': '2012-08-31', 'sentiment': 0.0},
#   {'start': '2012-09-01', 'end': '2012-09-31', 'sentiment': 0.0},
#   {'start': '2012-10-01', 'end': '2012-10-31', 'sentiment': 0.0},
#   {'start': '2012-11-01', 'end': '2012-11-31', 'sentiment': 0.0},
#   {'start': '2012-12-01', 'end': '2012-12-31', 'sentiment': 0.0}]}

# %% [markdown]
# ---

# %%
#date_start = "2018-01-01"   # YYYY-MM-DD
#date_end = "2018-12-31"

# %%
# Get headlines given industry and target period
#for key in industry_headlines.keys():
#  industry_headlines[key] = get_headlines_by_industry(headlines_csv_df, industry_tickers, key, date_start, date_end)

# %%
#all_target_tickers = get_all_relevant_tickers(industry_tickers)
#print(len(all_target_tickers))
#print(all_target_tickers[:5])

#company_headlines_dict = test_get_company_headlines(headlines_csv_df, all_target_tickers, date_start, date_end)

# %%
#company_headlines_dict

# %%
# Industry sentiments
'''
for industry in industry_sentiments.keys():
  print("----------------------------------------------------------")
  print("industry:", industry)
  print(industry_headlines[industry])
  ind_head = [item[1] for item in industry_headlines[industry]]

  # I use 200 entries for testing
  ind_head = ind_head #[:200]

  print("ind head:", len(ind_head))

  ind_kw_sentiment_dict, ind_kw_count_dict = get_industry_info(ind_head, lemmatizer, conventional_company_names)
  print(ind_kw_sentiment_dict)
  ind_sentiment = get_industry_score(ind_kw_sentiment_dict, ind_kw_count_dict)

  print("sentiment dict:", len(ind_kw_sentiment_dict), "keyword count:", len(ind_kw_count_dict))
  print("industry score:", ind_sentiment)

  industry_sentiments[industry] = [ind_sentiment, ind_kw_sentiment_dict, ind_kw_count_dict]
'''
# Out:
# '\nfor industry in industry_sentiments.keys():\n  print("----------------------------------------------------------")\n  print("industry:", industry)\n  print(industry_headlines[industry])\n  ind_head = [item[1] for item in industry_headlines[industry]]\n\n  # I use 200 entries for testing\n  ind_head = ind_head #[:200]\n\n  print("ind head:", len(ind_head))\n\n  ind_kw_sentiment_dict, ind_kw_count_dict = get_industry_info(ind_head, lemmatizer, conventional_company_names)\n  print(ind_kw_sentiment_dict)\n  ind_sentiment = get_industry_score(ind_kw_sentiment_dict, ind_kw_count_dict)\n\n  print("sentiment dict:", len(ind_kw_sentiment_dict), "keyword count:", len(ind_kw_count_dict))\n  print("industry score:", ind_sentiment)\n\n  industry_sentiments[industry] = [ind_sentiment, ind_kw_sentiment_dict, ind_kw_count_dict]\n'

# %%
'''
# keywords for "internet-content-and-information"
print("Industry:", industry_names[0])
print("Industry sentiment:", industry_sentiments[industry_names[0]][0])
print("Industry keywords:")
industry_sentiments[industry_names[0]][1].keys()
'''
# Out:
# '\n# keywords for "internet-content-and-information"\nprint("Industry:", industry_names[0])\nprint("Industry sentiment:", industry_sentiments[industry_names[0]][0])\nprint("Industry keywords:")\nindustry_sentiments[industry_names[0]][1].keys()\n'

# %%
'''
# keywords for "entertainment"
print("Industry:", industry_names[1])
print("Industry sentiment:", industry_sentiments[industry_names[1]][0])
print("Industry keywords:")
industry_sentiments[industry_names[1]][1].keys()
'''
# Out:
# '\n# keywords for "entertainment"\nprint("Industry:", industry_names[1])\nprint("Industry sentiment:", industry_sentiments[industry_names[1]][0])\nprint("Industry keywords:")\nindustry_sentiments[industry_names[1]][1].keys()\n'

# %%
'''
# keywords for "travel services"
print("Industry:", industry_names[2])
print("Industry sentiment:", industry_sentiments[industry_names[2]][0])
print("Industry keywords:")
industry_sentiments[industry_names[2]][1].keys()
'''
# Out:
# '\n# keywords for "travel services"\nprint("Industry:", industry_names[2])\nprint("Industry sentiment:", industry_sentiments[industry_names[2]][0])\nprint("Industry keywords:")\nindustry_sentiments[industry_names[2]][1].keys()\n'

# %%
# test run keywords
'''
print("Example: Travel Services")
print("Inudstry sentiment score:", industry_sentiments["Travel Services"][0], "\n")

ts_test_keys = ["caribbean", "norwegian", "hurricane", "booking", "revenue"]

print("sentiment scores of some keywords:")

for key in ts_test_keys:
  total_sent = industry_sentiments["Travel Services"][1][key]
  total_count = industry_sentiments["Travel Services"][2][key]
  print(key, total_sent / total_count)
'''
# Out:
# '\nprint("Example: Travel Services")\nprint("Inudstry sentiment score:", industry_sentiments["Travel Services"][0], "\n")\n\nts_test_keys = ["caribbean", "norwegian", "hurricane", "booking", "revenue"]\n\nprint("sentiment scores of some keywords:")\n\nfor key in ts_test_keys:\n  total_sent = industry_sentiments["Travel Services"][1][key]\n  total_count = industry_sentiments["Travel Services"][2][key]\n  print(key, total_sent / total_count)\n'

# %%
# Company final sentiments
'''
for industry in industry_tickers.keys():
  target_tickers_list = industry_tickers[industry]
  now_industry_sentiment = industry_sentiments[industry][0]
  now_industry_company_sentiment = dict()

  print("Industry:", industry)
  print("Industry sentiment:", now_industry_sentiment)

  for now_ticker in target_tickers_list:
    print("company:", now_ticker)
    company_name_skip_list = []

    for key, val in conventional_company_names.items():
      if key != now_ticker:
        company_name_skip_list.append(val)

    now_company_allnews_sent, now_company_subset_sent = get_company_subset(company_headlines_dict, now_ticker, industry_sentiments[industry][1], company_name_skip_list)

    if len(now_company_allnews_sent) >= 1:
      now_company_allnews_score = sum(list(now_company_allnews_sent.values())) / len(now_company_allnews_sent)
    else:
      now_company_allnews_score = 0

    if len(now_company_subset_sent) >= 1:
      now_company_subset_score = sum(list(now_company_subset_sent.values())) / len(now_company_subset_sent)
    else:
      now_company_subset_score = 0

    print("company_allnews_sentiment:", now_company_allnews_sent)
    print("company_subset_sentiment:", now_company_subset_sent)

    print("company score (all news concerned):", now_company_allnews_score)
    print("company score (as influenced by industry):", now_company_subset_score)

    ###################################

    now_company_rel_score = (now_company_allnews_score + now_company_subset_score) / 2
    now_company_final_score = now_industry_sentiment + now_company_rel_score

    now_industry_company_sentiment[now_ticker] = now_company_final_score

    print("company relevant [(now_company_allnews_score + now_company_subset_score) /2]: ", now_company_rel_score)
    print("company final score: (industry_sentiment + now_company_rel_score)", now_company_final_score)

  industry_company_sentiments[industry] = now_industry_company_sentiment
'''
# Out:
# '\nfor industry in industry_tickers.keys():\n  target_tickers_list = industry_tickers[industry]\n  now_industry_sentiment = industry_sentiments[industry][0]\n  now_industry_company_sentiment = dict()\n\n  print("Industry:", industry)\n  print("Industry sentiment:", now_industry_sentiment)\n\n  for now_ticker in target_tickers_list:\n    print("company:", now_ticker)\n    company_name_skip_list = []\n\n    for key, val in conventional_company_names.items():\n      if key != now_ticker:\n        company_name_skip_list.append(val)\n\n    now_company_allnews_sent, now_company_subset_sent = get_company_subset(company_headlines_dict, now_ticker, industry_sentiments[industry][1], company_name_skip_list)\n\n    if len(now_company_allnews_sent) >= 1:\n      now_company_allnews_score = sum(list(now_company_allnews_sent.values())) / len(now_company_allnews_sent)\n    else:\n      now_company_allnews_score = 0\n\n    if len(now_company_subset_sent) >= 1:\n      now_company_subset_score = sum(list(now_company_subset_sent.values())) / len(now_company_subset_sent)\n    else:\n      now_company_subset_score = 0\n\n    print("company_allnews_sentiment:", now_company_allnews_sent)\n    print("company_subset_sentiment:", now_company_subset_sent)\n\n    print("company score (all news concerned):", now_company_allnews_score)\n    print("company score (as influenced by industry):", now_company_subset_score)\n\n    ###################################\n\n    now_company_rel_score = (now_company_allnews_score + now_company_subset_score) / 2\n    now_company_final_score = now_industry_sentiment + now_company_rel_score\n\n    now_industry_company_sentiment[now_ticker] = now_company_final_score\n\n    print("company relevant [(now_company_allnews_score + now_company_subset_score) /2]: ", now_company_rel_score)\n    print("company final score: (industry_sentiment + now_company_rel_score)", now_company_final_score)\n\n  industry_company_sentiments[industry] = now_industry_company_sentiment\n'

# %% [markdown]
# ## Final sentiments of companies in each industry

# %%
#print("Inudstry:", industry_names[0])
#industry_company_sentiments[industry_names[0]]

# %%
#print("Industry:", industry_names[1])
#industry_company_sentiments[industry_names[1]]

# %%
#print("Industry:", industry_names[2])
#industry_company_sentiments[industry_names[2]]

# %% [markdown]
# ## Output json file

# %%
with open(output_base_path + "industry_" + period_start + "_" + date_end + ".json", "w") as f:
   json.dump(json_industry, f)

# %%
with open(output_base_path+"company_" + period_start + "_" + date_end + ".json", "w") as f:
   json.dump(json_company, f)
